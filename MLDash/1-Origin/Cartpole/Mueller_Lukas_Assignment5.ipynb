# %% [markdown]
# # Module Five Assignment: Cartpole Problem
# Review the code in this notebook and in the score_logger.py file in the *scores* folder (directory). Once you have reviewed the code, return to this notebook and select **Cell** and then **Run All** from the menu bar to run this code. The code takes several minutes to run.

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.95  
LEARNING_RATE = 0.001  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()
# Out:
# C:\Users\Bringer_of_Light\anaconda3\envs\370\lib\site-packages\h5py\__init__.py:46: DeprecationWarning: `np.typeDict` is a deprecated alias for `np.sctypeDict`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# C:\Users\Bringer_of_Light\anaconda3\envs\370\lib\site-packages\tensorflow\python\util\nest.py:1286: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   _pywrap_tensorflow.RegisterType("Mapping", _collections.Mapping)
# C:\Users\Bringer_of_Light\anaconda3\envs\370\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Bringer_of_Light\anaconda3\envs\370\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Bringer_of_Light\anaconda3\envs\370\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Bringer_of_Light\anaconda3\envs\370\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Bringer_of_Light\anaconda3\envs\370\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Bringer_of_Light\anaconda3\envs\370\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\Bringer_of_Light\anaconda3\envs\370\lib\site-packages\tensorflow\python\framework\dtypes.py:593: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   np.object,
# C:\Users\Bringer_of_Light\anaconda3\envs\370\lib\site-packages\tensorflow\python\framework\dtypes.py:601: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   np.bool,
# C:\Users\Bringer_of_Light\anaconda3\envs\370\lib\site-packages\tensorflow\python\framework\tensor_util.py:174: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   np.object: SlowAppendObjectArrayToTensorProto,
# C:\Users\Bringer_of_Light\anaconda3\envs\370\lib\site-packages\tensorflow\python\framework\tensor_util.py:175: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   np.bool: SlowAppendBoolArrayToTensorProto,
# C:\Users\Bringer_of_Light\anaconda3\envs\370\lib\site-packages\tensorflow\python\training\tracking\object_identity.py:61: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   class ObjectIdentityDictionary(collections.MutableMapping):
# C:\Users\Bringer_of_Light\anaconda3\envs\370\lib\site-packages\tensorflow\python\training\tracking\data_structures.py:374: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   class _ListWrapper(List, collections.MutableSequence,
# C:\Users\Bringer_of_Light\anaconda3\envs\370\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Bringer_of_Light\anaconda3\envs\370\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Bringer_of_Light\anaconda3\envs\370\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Bringer_of_Light\anaconda3\envs\370\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Bringer_of_Light\anaconda3\envs\370\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Bringer_of_Light\anaconda3\envs\370\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\Bringer_of_Light\anaconda3\envs\370\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:568: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   (np.object, string),
# C:\Users\Bringer_of_Light\anaconda3\envs\370\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:569: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   (np.bool, bool),
# C:\Users\Bringer_of_Light\anaconda3\envs\370\lib\site-packages\tensorboard\util\tensor_util.py:100: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   np.object: SlowAppendObjectArrayToTensorProto,
# C:\Users\Bringer_of_Light\anaconda3\envs\370\lib\site-packages\tensorboard\util\tensor_util.py:101: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   np.bool: SlowAppendBoolArrayToTensorProto,
# C:\Users\Bringer_of_Light\anaconda3\envs\370\lib\site-packages\keras\callbacks\callbacks.py:19: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   from collections import Iterable

# %%
cartpole()
# Out:
# C:\Users\Bringer_of_Light\anaconda3\envs\370\lib\site-packages\tensorflow\python\framework\tensor_util.py:538: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   tensor_proto.tensor_content = nparray.tostring()
# WARNING:tensorflow:From C:\Users\Bringer_of_Light\anaconda3\envs\370\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Run: 1, exploration: 0.918316468354365, score: 37
# Scores: (min: 37, avg: 37, max: 37)
#
# Run: 2, exploration: 0.8603841919146962, score: 14
# Scores: (min: 14, avg: 25.5, max: 37)
#
# Run: 3, exploration: 0.6935613678313175, score: 44
# Scores: (min: 14, avg: 31.666666666666668, max: 44)
#
# Run: 4, exploration: 0.653073201944699, score: 13
# Scores: (min: 13, avg: 27, max: 44)
#
# Run: 5, exploration: 0.6180388156137953, score: 12
# Scores: (min: 12, avg: 24, max: 44)
#
# Run: 6, exploration: 0.5878229785513479, score: 11
# Scores: (min: 11, avg: 21.833333333333332, max: 44)
#
# Run: 7, exploration: 0.5425201222922789, score: 17
# Scores: (min: 11, avg: 21.142857142857142, max: 44)
#
# Run: 8, exploration: 0.5185893309484582, score: 10
# Scores: (min: 10, avg: 19.75, max: 44)
#
# Run: 9, exploration: 0.4932355662165453, score: 11
# Scores: (min: 10, avg: 18.77777777777778, max: 44)
#
# Run: 10, exploration: 0.4598090507939749, score: 15
# Scores: (min: 10, avg: 18.4, max: 44)
#
# Run: 11, exploration: 0.42013897252428334, score: 19
# Scores: (min: 10, avg: 18.454545454545453, max: 44)
#
# Run: 12, exploration: 0.4016064652978155, score: 10
# Scores: (min: 10, avg: 17.75, max: 44)
#
# Run: 13, exploration: 0.3819719776053028, score: 11
# Scores: (min: 10, avg: 17.23076923076923, max: 44)
#
# Run: 14, exploration: 0.3578751580867638, score: 14
# Scores: (min: 10, avg: 17, max: 44)
#
# Run: 15, exploration: 0.3438081748424137, score: 9
# Scores: (min: 9, avg: 16.466666666666665, max: 44)
#
# Run: 16, exploration: 0.3302941218954743, score: 9
# Scores: (min: 9, avg: 16, max: 44)
#
# Run: 17, exploration: 0.3125753549412418, score: 12
# Scores: (min: 9, avg: 15.764705882352942, max: 44)
#
# Run: 18, exploration: 0.2943280830920294, score: 13
# Scores: (min: 9, avg: 15.61111111111111, max: 44)
#
# Run: 19, exploration: 0.2757603055760701, score: 14
# Scores: (min: 9, avg: 15.526315789473685, max: 44)
#
# Run: 20, exploration: 0.26227842021373715, score: 11
# Scores: (min: 9, avg: 15.3, max: 44)
#
# Run: 21, exploration: 0.2532352299289372, score: 8
# Scores: (min: 8, avg: 14.952380952380953, max: 44)
#
# Run: 22, exploration: 0.24206491716205145, score: 10
# Scores: (min: 8, avg: 14.727272727272727, max: 44)
#
# Run: 23, exploration: 0.231387331601191, score: 10
# Scores: (min: 8, avg: 14.521739130434783, max: 44)
#
# Run: 24, exploration: 0.2189744609715989, score: 12
# Scores: (min: 8, avg: 14.416666666666666, max: 44)
#
# Run: 25, exploration: 0.21036724137609603, score: 9
# Scores: (min: 8, avg: 14.2, max: 44)
#
# Run: 26, exploration: 0.19808659230739353, score: 13
# Scores: (min: 8, avg: 14.153846153846153, max: 44)
#
# Run: 27, exploration: 0.18840216465300522, score: 11
# Scores: (min: 8, avg: 14.037037037037036, max: 44)
#
# Run: 28, exploration: 0.18099664897669618, score: 9
# Scores: (min: 8, avg: 13.857142857142858, max: 44)
#
# Run: 29, exploration: 0.1730128104744653, score: 10
# Scores: (min: 8, avg: 13.724137931034482, max: 44)
#
# Run: 30, exploration: 0.16373146555890544, score: 12
# Scores: (min: 8, avg: 13.666666666666666, max: 44)
#
# Run: 31, exploration: 0.1526354036900377, score: 15
# Scores: (min: 8, avg: 13.709677419354838, max: 44)
#
# Run: 32, exploration: 0.14444721332374086, score: 12
# Scores: (min: 8, avg: 13.65625, max: 44)
#
# Run: 33, exploration: 0.13601479046086049, score: 13
# Scores: (min: 8, avg: 13.636363636363637, max: 44)
#
# Run: 34, exploration: 0.13066846301911936, score: 9
# Scores: (min: 8, avg: 13.5, max: 44)
#
# Run: 35, exploration: 0.11643985070121858, score: 24
# Scores: (min: 8, avg: 13.8, max: 44)
#
# Run: 36, exploration: 0.10800599224428936, score: 16
# Scores: (min: 8, avg: 13.86111111111111, max: 44)
#
# Run: 37, exploration: 0.10221196540767843, score: 12
# Scores: (min: 8, avg: 13.81081081081081, max: 44)
#
# Run: 38, exploration: 0.09576389217857617, score: 14
# Scores: (min: 8, avg: 13.81578947368421, max: 44)
#
# Run: 39, exploration: 0.08972259762946533, score: 14
# Scores: (min: 8, avg: 13.820512820512821, max: 44)
#
# Run: 40, exploration: 0.08239373898667031, score: 18
# Scores: (min: 8, avg: 13.925, max: 44)
#
# Run: 41, exploration: 0.06983222438783, score: 34
# Scores: (min: 8, avg: 14.414634146341463, max: 44)
#
# Run: 42, exploration: 0.05918580250061433, score: 34
# Scores: (min: 8, avg: 14.880952380952381, max: 44)
#
# Run: 43, exploration: 0.05517478773284426, score: 15
# Scores: (min: 8, avg: 14.883720930232558, max: 44)
#
# Run: 44, exploration: 0.051178420962124486, score: 16
# Scores: (min: 8, avg: 14.909090909090908, max: 44)
#
# Run: 45, exploration: 0.046296535966244, score: 21
# Scores: (min: 8, avg: 15.044444444444444, max: 44)
#
# Run: 46, exploration: 0.04063952250178857, score: 27
# Scores: (min: 8, avg: 15.304347826086957, max: 44)
#
# Run: 47, exploration: 0.034271518052411715, score: 35
# Scores: (min: 8, avg: 15.72340425531915, max: 44)
#
# Run: 48, exploration: 0.02948667236521416, score: 31
# Scores: (min: 8, avg: 16.041666666666668, max: 44)
#
# Run: 49, exploration: 0.024618221284683196, score: 37
# Scores: (min: 8, avg: 16.46938775510204, max: 44)
#
# Run: 50, exploration: 0.021827832324362372, score: 25
# Scores: (min: 8, avg: 16.64, max: 44)
#
# Run: 51, exploration: 0.019944633602480003, score: 19
# Scores: (min: 8, avg: 16.686274509803923, max: 44)
#
# Run: 52, exploration: 0.017160047465104442, score: 31
# Scores: (min: 8, avg: 16.96153846153846, max: 44)
#
# Run: 53, exploration: 0.015215016325303928, score: 25
# Scores: (min: 8, avg: 17.11320754716981, max: 44)
#
# Run: 54, exploration: 0.012960179199743523, score: 33
# Scores: (min: 8, avg: 17.40740740740741, max: 44)
#
# Run: 55, exploration: 0.01, score: 59
# Scores: (min: 8, avg: 18.163636363636364, max: 59)
#
# Run: 56, exploration: 0.01, score: 59
# Scores: (min: 8, avg: 18.892857142857142, max: 59)
#
# Run: 57, exploration: 0.01, score: 104
# Scores: (min: 8, avg: 20.385964912280702, max: 104)
#
# Run: 58, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 20.43103448275862, max: 104)
#
# Run: 59, exploration: 0.01, score: 42
# Scores: (min: 8, avg: 20.796610169491526, max: 104)
#
# Run: 60, exploration: 0.01, score: 70
# Scores: (min: 8, avg: 21.616666666666667, max: 104)
#
# Run: 61, exploration: 0.01, score: 43
# Scores: (min: 8, avg: 21.9672131147541, max: 104)
#
# Run: 62, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 22.20967741935484, max: 104)
#
# Run: 63, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 22.253968253968253, max: 104)
#
# Run: 64, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 22.390625, max: 104)
#
# Run: 65, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 22.43076923076923, max: 104)
#
# Run: 66, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 22.46969696969697, max: 104)
#
# Run: 67, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 22.417910447761194, max: 104)
#
# Run: 68, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 22.36764705882353, max: 104)
#
# Run: 69, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 22.47826086956522, max: 104)
#
# Run: 70, exploration: 0.01, score: 52
# Scores: (min: 8, avg: 22.9, max: 104)
#
# Run: 71, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 22.971830985915492, max: 104)
#
# Run: 72, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 22.97222222222222, max: 104)
#
# Run: 73, exploration: 0.01, score: 40
# Scores: (min: 8, avg: 23.205479452054796, max: 104)
#
# Run: 74, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 23.22972972972973, max: 104)
#
# Run: 75, exploration: 0.01, score: 71
# Scores: (min: 8, avg: 23.866666666666667, max: 104)
#
# Run: 76, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 23.973684210526315, max: 104)
#
# Run: 77, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 24.07792207792208, max: 104)
#
# Run: 78, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 24.115384615384617, max: 104)
#
# Run: 79, exploration: 0.01, score: 48
# Scores: (min: 8, avg: 24.417721518987342, max: 104)
#
# Run: 80, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 24.5125, max: 104)
#
# Run: 81, exploration: 0.01, score: 38
# Scores: (min: 8, avg: 24.679012345679013, max: 104)
#
# Run: 82, exploration: 0.01, score: 83
# Scores: (min: 8, avg: 25.390243902439025, max: 104)
#
# Run: 83, exploration: 0.01, score: 47
# Scores: (min: 8, avg: 25.650602409638555, max: 104)
# Run: 84, exploration: 0.01, score: 66
# Scores: (min: 8, avg: 26.13095238095238, max: 104)
#
# Run: 85, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 26.03529411764706, max: 104)
#
# Run: 86, exploration: 0.01, score: 132
# Scores: (min: 8, avg: 27.267441860465116, max: 132)
#
# Run: 87, exploration: 0.01, score: 88
# Scores: (min: 8, avg: 27.96551724137931, max: 132)
#
# Run: 88, exploration: 0.01, score: 67
# Scores: (min: 8, avg: 28.40909090909091, max: 132)
#
# Run: 89, exploration: 0.01, score: 139
# Scores: (min: 8, avg: 29.651685393258425, max: 139)
#
# Run: 90, exploration: 0.01, score: 119
# Scores: (min: 8, avg: 30.644444444444446, max: 139)
#
# Run: 91, exploration: 0.01, score: 160
# Scores: (min: 8, avg: 32.065934065934066, max: 160)
#
# Run: 92, exploration: 0.01, score: 177
# Scores: (min: 8, avg: 33.641304347826086, max: 177)
#
# Run: 93, exploration: 0.01, score: 189
# Scores: (min: 8, avg: 35.31182795698925, max: 189)
#
# Run: 94, exploration: 0.01, score: 243
# Scores: (min: 8, avg: 37.52127659574468, max: 243)
#
# Run: 95, exploration: 0.01, score: 153
# Scores: (min: 8, avg: 38.73684210526316, max: 243)
#
# Run: 96, exploration: 0.01, score: 124
# Scores: (min: 8, avg: 39.625, max: 243)
#
# Run: 97, exploration: 0.01, score: 181
# Scores: (min: 8, avg: 41.08247422680412, max: 243)
#
# Run: 98, exploration: 0.01, score: 161
# Scores: (min: 8, avg: 42.30612244897959, max: 243)
#
# Run: 99, exploration: 0.01, score: 188
# Scores: (min: 8, avg: 43.77777777777778, max: 243)
#
# Run: 100, exploration: 0.01, score: 180
# Scores: (min: 8, avg: 45.14, max: 243)
#
# Run: 101, exploration: 0.01, score: 138
# Scores: (min: 8, avg: 46.15, max: 243)
#
# Run: 102, exploration: 0.01, score: 139
# Scores: (min: 8, avg: 47.4, max: 243)
#
# Run: 103, exploration: 0.01, score: 196
# Scores: (min: 8, avg: 48.92, max: 243)
#
# Run: 104, exploration: 0.01, score: 171
# Scores: (min: 8, avg: 50.5, max: 243)
#
# Run: 105, exploration: 0.01, score: 341
# Scores: (min: 8, avg: 53.79, max: 341)
#
# Run: 106, exploration: 0.01, score: 160
# Scores: (min: 8, avg: 55.28, max: 341)
#
# Run: 107, exploration: 0.01, score: 219
# Scores: (min: 8, avg: 57.3, max: 341)
#
# Run: 108, exploration: 0.01, score: 153
# Scores: (min: 8, avg: 58.73, max: 341)
#
# Run: 109, exploration: 0.01, score: 177
# Scores: (min: 8, avg: 60.39, max: 341)
#
# Run: 110, exploration: 0.01, score: 204
# Scores: (min: 8, avg: 62.28, max: 341)
#
# Run: 111, exploration: 0.01, score: 199
# Scores: (min: 8, avg: 64.08, max: 341)
#
# Run: 112, exploration: 0.01, score: 161
# Scores: (min: 8, avg: 65.59, max: 341)
#
# Run: 113, exploration: 0.01, score: 282
# Scores: (min: 8, avg: 68.3, max: 341)
#
# Run: 114, exploration: 0.01, score: 196
# Scores: (min: 8, avg: 70.12, max: 341)
#
# Run: 115, exploration: 0.01, score: 186
# Scores: (min: 8, avg: 71.89, max: 341)
#
# Run: 116, exploration: 0.01, score: 197
# Scores: (min: 8, avg: 73.77, max: 341)
#
# Run: 117, exploration: 0.01, score: 349
# Scores: (min: 8, avg: 77.14, max: 349)
#
# Run: 118, exploration: 0.01, score: 172
# Scores: (min: 8, avg: 78.73, max: 349)
#
# Run: 119, exploration: 0.01, score: 225
# Scores: (min: 8, avg: 80.84, max: 349)
#
# Run: 120, exploration: 0.01, score: 190
# Scores: (min: 8, avg: 82.63, max: 349)
#
# Run: 121, exploration: 0.01, score: 190
# Scores: (min: 9, avg: 84.45, max: 349)
#
# Run: 122, exploration: 0.01, score: 218
# Scores: (min: 9, avg: 86.53, max: 349)
#
# Run: 123, exploration: 0.01, score: 221
# Scores: (min: 9, avg: 88.64, max: 349)
#
# Run: 124, exploration: 0.01, score: 193
# Scores: (min: 9, avg: 90.45, max: 349)
#
# Run: 125, exploration: 0.01, score: 206
# Scores: (min: 9, avg: 92.42, max: 349)
#
# Run: 126, exploration: 0.01, score: 259
# Scores: (min: 9, avg: 94.88, max: 349)
#
# Run: 127, exploration: 0.01, score: 295
# Scores: (min: 9, avg: 97.72, max: 349)
#
# Run: 128, exploration: 0.01, score: 146
# Scores: (min: 9, avg: 99.09, max: 349)
#
# Run: 129, exploration: 0.01, score: 211
# Scores: (min: 9, avg: 101.1, max: 349)
#
# Run: 130, exploration: 0.01, score: 234
# Scores: (min: 9, avg: 103.32, max: 349)
#
# Run: 131, exploration: 0.01, score: 141
# Scores: (min: 9, avg: 104.58, max: 349)
#
# Run: 132, exploration: 0.01, score: 183
# Scores: (min: 9, avg: 106.29, max: 349)
#
# Run: 133, exploration: 0.01, score: 443
# Scores: (min: 9, avg: 110.59, max: 443)
#
# Run: 134, exploration: 0.01, score: 261
# Scores: (min: 12, avg: 113.11, max: 443)
#
# Run: 135, exploration: 0.01, score: 312
# Scores: (min: 12, avg: 115.99, max: 443)
#
# Run: 136, exploration: 0.01, score: 173
# Scores: (min: 12, avg: 117.56, max: 443)
#
# Run: 137, exploration: 0.01, score: 251
# Scores: (min: 14, avg: 119.95, max: 443)
#
# Run: 138, exploration: 0.01, score: 353
# Scores: (min: 14, avg: 123.34, max: 443)
#
# Run: 139, exploration: 0.01, score: 176
# Scores: (min: 15, avg: 124.96, max: 443)
#
# Run: 140, exploration: 0.01, score: 190
# Scores: (min: 15, avg: 126.68, max: 443)
#
# Run: 141, exploration: 0.01, score: 185
# Scores: (min: 15, avg: 128.19, max: 443)
#
# Run: 142, exploration: 0.01, score: 230
# Scores: (min: 15, avg: 130.15, max: 443)
#
# Run: 143, exploration: 0.01, score: 195
# Scores: (min: 16, avg: 131.95, max: 443)
#
# Run: 144, exploration: 0.01, score: 435
# Scores: (min: 18, avg: 136.14, max: 443)
#
# Run: 145, exploration: 0.01, score: 207
# Scores: (min: 18, avg: 138, max: 443)
#
# Run: 146, exploration: 0.01, score: 219
# Scores: (min: 18, avg: 139.92, max: 443)
#
# Run: 147, exploration: 0.01, score: 216
# Scores: (min: 18, avg: 141.73, max: 443)
#
# Run: 148, exploration: 0.01, score: 201
# Scores: (min: 18, avg: 143.43, max: 443)
#
# Run: 149, exploration: 0.01, score: 287
# Scores: (min: 18, avg: 145.93, max: 443)
#
# Run: 150, exploration: 0.01, score: 185
# Scores: (min: 18, avg: 147.53, max: 443)
#
# Run: 151, exploration: 0.01, score: 148
# Scores: (min: 18, avg: 148.82, max: 443)
#
# Run: 152, exploration: 0.01, score: 206
# Scores: (min: 18, avg: 150.57, max: 443)
#
# Run: 153, exploration: 0.01, score: 282
# Scores: (min: 18, avg: 153.14, max: 443)
#
# Run: 154, exploration: 0.01, score: 288
# Scores: (min: 18, avg: 155.69, max: 443)
#
# Run: 155, exploration: 0.01, score: 218
# Scores: (min: 18, avg: 157.28, max: 443)
#
# Run: 156, exploration: 0.01, score: 191
# Scores: (min: 18, avg: 158.6, max: 443)
#
# Run: 157, exploration: 0.01, score: 196
# Scores: (min: 18, avg: 159.52, max: 443)
#
# Run: 158, exploration: 0.01, score: 255
# Scores: (min: 18, avg: 161.84, max: 443)
#
# Run: 159, exploration: 0.01, score: 284
# Scores: (min: 18, avg: 164.26, max: 443)
#
# Run: 160, exploration: 0.01, score: 269
# Scores: (min: 18, avg: 166.25, max: 443)
#
# Run: 161, exploration: 0.01, score: 438
# Scores: (min: 18, avg: 170.2, max: 443)
#
# Run: 162, exploration: 0.01, score: 188
# Scores: (min: 18, avg: 171.71, max: 443)
#
# Run: 163, exploration: 0.01, score: 232
# Scores: (min: 18, avg: 173.78, max: 443)
#
# Run: 164, exploration: 0.01, score: 264
# Scores: (min: 18, avg: 176.11, max: 443)
#
# Run: 165, exploration: 0.01, score: 230
# Scores: (min: 18, avg: 178.16, max: 443)
#
# Run: 166, exploration: 0.01, score: 273
# Scores: (min: 18, avg: 180.64, max: 443)
#
# Run: 167, exploration: 0.01, score: 194
# Scores: (min: 18, avg: 182.39, max: 443)
#
# Run: 168, exploration: 0.01, score: 238
# Scores: (min: 18, avg: 184.58, max: 443)
#
# Run: 169, exploration: 0.01, score: 244
# Scores: (min: 18, avg: 186.72, max: 443)
#
# Run: 170, exploration: 0.01, score: 285
# Scores: (min: 18, avg: 189.05, max: 443)
#
# Run: 171, exploration: 0.01, score: 399
# Scores: (min: 18, avg: 192.76, max: 443)
#
# Run: 172, exploration: 0.01, score: 297
# Scores: (min: 18, avg: 195.5, max: 443)
#
# Solved in 72 runs, 172 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9888\682879775.py in <module>
# ----> 1 cartpole()
#
# ~\AppData\Local\Temp\ipykernel_9888\1927976810.py in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# ~\1CS-370\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.95  
LEARNING_RATE = 0.002  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()

# %%
cartpole()
# Out:
# Run: 1, exploration: 1.0, score: 10
# Scores: (min: 10, avg: 10, max: 10)
#
# Run: 2, exploration: 0.960693043575437, score: 18
# Scores: (min: 10, avg: 14, max: 18)
#
# Run: 3, exploration: 0.9091562615825302, score: 12
# Scores: (min: 10, avg: 13.333333333333334, max: 18)
#
# Run: 4, exploration: 0.8348931673187264, score: 18
# Scores: (min: 10, avg: 14.5, max: 18)
#
# Run: 5, exploration: 0.7111635524897149, score: 33
# Scores: (min: 10, avg: 18.2, max: 33)
#
# Run: 6, exploration: 0.6465587967553006, score: 20
# Scores: (min: 10, avg: 18.5, max: 33)
#
# Run: 7, exploration: 0.6211445383053219, score: 9
# Scores: (min: 9, avg: 17.142857142857142, max: 33)
#
# Run: 8, exploration: 0.5967292370047992, score: 9
# Scores: (min: 9, avg: 16.125, max: 33)
#
# Run: 9, exploration: 0.567555222460375, score: 11
# Scores: (min: 9, avg: 15.555555555555555, max: 33)
#
# Run: 10, exploration: 0.5290920728090721, score: 15
# Scores: (min: 9, avg: 15.5, max: 33)
#
# Run: 11, exploration: 0.4932355662165453, score: 15
# Scores: (min: 9, avg: 15.454545454545455, max: 33)
#
# Run: 12, exploration: 0.36880183088056995, score: 59
# Scores: (min: 9, avg: 19.083333333333332, max: 59)
#
# Run: 13, exploration: 0.31890579420988907, score: 30
# Scores: (min: 9, avg: 19.923076923076923, max: 59)
#
# Run: 14, exploration: 0.23725980767521673, score: 60
# Scores: (min: 9, avg: 22.785714285714285, max: 60)
#
# Run: 15, exploration: 0.17043057265153258, score: 67
# Scores: (min: 9, avg: 25.733333333333334, max: 67)
#
# Run: 16, exploration: 0.13331482894782642, score: 50
# Scores: (min: 9, avg: 27.25, max: 67)
#
# Run: 17, exploration: 0.11186295456362313, score: 36
# Scores: (min: 9, avg: 27.764705882352942, max: 67)
#
# Run: 18, exploration: 0.08364210790237678, score: 59
# Scores: (min: 9, avg: 29.5, max: 67)
#
# Run: 19, exploration: 0.048432933065126825, score: 110
# Scores: (min: 9, avg: 33.73684210526316, max: 110)
#
# Run: 20, exploration: 0.02707809682994571, score: 117
# Scores: (min: 9, avg: 37.9, max: 117)
#
# Run: 21, exploration: 0.02437265452736848, score: 22
# Scores: (min: 9, avg: 37.142857142857146, max: 117)
#
# Run: 22, exploration: 0.016735314893855303, score: 76
# Scores: (min: 9, avg: 38.90909090909091, max: 117)
#
# Run: 23, exploration: 0.01, score: 112
# Scores: (min: 9, avg: 42.08695652173913, max: 117)
#
# Run: 24, exploration: 0.01, score: 235
# Scores: (min: 9, avg: 50.125, max: 235)
#
# Run: 25, exploration: 0.01, score: 198
# Scores: (min: 9, avg: 56.04, max: 235)
#
# Run: 26, exploration: 0.01, score: 176
# Scores: (min: 9, avg: 60.65384615384615, max: 235)
#
# Run: 27, exploration: 0.01, score: 262
# Scores: (min: 9, avg: 68.11111111111111, max: 262)
#
# Run: 28, exploration: 0.01, score: 163
# Scores: (min: 9, avg: 71.5, max: 262)
#
# Run: 29, exploration: 0.01, score: 347
# Scores: (min: 9, avg: 81, max: 347)
#
# Run: 30, exploration: 0.01, score: 163
# Scores: (min: 9, avg: 83.73333333333333, max: 347)
#
# Run: 31, exploration: 0.01, score: 163
# Scores: (min: 9, avg: 86.29032258064517, max: 347)
#
# Run: 32, exploration: 0.01, score: 168
# Scores: (min: 9, avg: 88.84375, max: 347)
#
# Run: 33, exploration: 0.01, score: 188
# Scores: (min: 9, avg: 91.84848484848484, max: 347)
#
# Run: 34, exploration: 0.01, score: 153
# Scores: (min: 9, avg: 93.6470588235294, max: 347)
#
# Run: 35, exploration: 0.01, score: 137
# Scores: (min: 9, avg: 94.88571428571429, max: 347)
#
# Run: 36, exploration: 0.01, score: 126
# Scores: (min: 9, avg: 95.75, max: 347)
#
# Run: 37, exploration: 0.01, score: 224
# Scores: (min: 9, avg: 99.21621621621621, max: 347)
#
# Run: 38, exploration: 0.01, score: 289
# Scores: (min: 9, avg: 104.21052631578948, max: 347)
#
# Run: 39, exploration: 0.01, score: 171
# Scores: (min: 9, avg: 105.92307692307692, max: 347)
#
# Run: 40, exploration: 0.01, score: 145
# Scores: (min: 9, avg: 106.9, max: 347)
#
# Run: 41, exploration: 0.01, score: 169
# Scores: (min: 9, avg: 108.41463414634147, max: 347)
#
# Run: 42, exploration: 0.01, score: 274
# Scores: (min: 9, avg: 112.35714285714286, max: 347)
#
# Run: 43, exploration: 0.01, score: 239
# Scores: (min: 9, avg: 115.30232558139535, max: 347)
#
# Run: 44, exploration: 0.01, score: 178
# Scores: (min: 9, avg: 116.72727272727273, max: 347)
#
# Run: 45, exploration: 0.01, score: 167
# Scores: (min: 9, avg: 117.84444444444445, max: 347)
#
# Run: 46, exploration: 0.01, score: 206
# Scores: (min: 9, avg: 119.76086956521739, max: 347)
#
# Run: 47, exploration: 0.01, score: 174
# Scores: (min: 9, avg: 120.91489361702128, max: 347)
#
# Run: 48, exploration: 0.01, score: 203
# Scores: (min: 9, avg: 122.625, max: 347)
#
# Run: 49, exploration: 0.01, score: 217
# Scores: (min: 9, avg: 124.55102040816327, max: 347)
#
# Run: 50, exploration: 0.01, score: 149
# Scores: (min: 9, avg: 125.04, max: 347)
#
# Run: 51, exploration: 0.01, score: 164
# Scores: (min: 9, avg: 125.80392156862744, max: 347)
#
# Run: 52, exploration: 0.01, score: 191
# Scores: (min: 9, avg: 127.0576923076923, max: 347)
#
# Run: 53, exploration: 0.01, score: 189
# Scores: (min: 9, avg: 128.22641509433961, max: 347)
#
# Run: 54, exploration: 0.01, score: 178
# Scores: (min: 9, avg: 129.14814814814815, max: 347)
#
# Run: 55, exploration: 0.01, score: 170
# Scores: (min: 9, avg: 129.8909090909091, max: 347)
#
# Run: 56, exploration: 0.01, score: 273
# Scores: (min: 9, avg: 132.44642857142858, max: 347)
#
# Run: 57, exploration: 0.01, score: 136
# Scores: (min: 9, avg: 132.50877192982455, max: 347)
#
# Run: 58, exploration: 0.01, score: 180
# Scores: (min: 9, avg: 133.32758620689654, max: 347)
#
# Run: 59, exploration: 0.01, score: 124
# Scores: (min: 9, avg: 133.16949152542372, max: 347)
#
# Run: 60, exploration: 0.01, score: 145
# Scores: (min: 9, avg: 133.36666666666667, max: 347)
#
# Run: 61, exploration: 0.01, score: 134
# Scores: (min: 9, avg: 133.37704918032787, max: 347)
#
# Run: 62, exploration: 0.01, score: 63
# Scores: (min: 9, avg: 132.24193548387098, max: 347)
#
# Run: 63, exploration: 0.01, score: 156
# Scores: (min: 9, avg: 132.61904761904762, max: 347)
#
# Run: 64, exploration: 0.01, score: 195
# Scores: (min: 9, avg: 133.59375, max: 347)
#
# Run: 65, exploration: 0.01, score: 171
# Scores: (min: 9, avg: 134.16923076923078, max: 347)
#
# Run: 66, exploration: 0.01, score: 149
# Scores: (min: 9, avg: 134.3939393939394, max: 347)
#
# Run: 67, exploration: 0.01, score: 228
# Scores: (min: 9, avg: 135.7910447761194, max: 347)
#
# Run: 68, exploration: 0.01, score: 157
# Scores: (min: 9, avg: 136.10294117647058, max: 347)
#
# Run: 69, exploration: 0.01, score: 163
# Scores: (min: 9, avg: 136.4927536231884, max: 347)
#
# Run: 70, exploration: 0.01, score: 141
# Scores: (min: 9, avg: 136.55714285714285, max: 347)
#
# Run: 71, exploration: 0.01, score: 168
# Scores: (min: 9, avg: 137, max: 347)
#
# Run: 72, exploration: 0.01, score: 147
# Scores: (min: 9, avg: 137.13888888888889, max: 347)
#
# Run: 73, exploration: 0.01, score: 154
# Scores: (min: 9, avg: 137.36986301369862, max: 347)
#
# Run: 74, exploration: 0.01, score: 153
# Scores: (min: 9, avg: 137.5810810810811, max: 347)
#
# Run: 75, exploration: 0.01, score: 137
# Scores: (min: 9, avg: 137.57333333333332, max: 347)
#
# Run: 76, exploration: 0.01, score: 166
# Scores: (min: 9, avg: 137.94736842105263, max: 347)
#
# Run: 77, exploration: 0.01, score: 222
# Scores: (min: 9, avg: 139.03896103896105, max: 347)
#
# Run: 78, exploration: 0.01, score: 233
# Scores: (min: 9, avg: 140.24358974358975, max: 347)
#
# Run: 79, exploration: 0.01, score: 31
# Scores: (min: 9, avg: 138.86075949367088, max: 347)
#
# Run: 80, exploration: 0.01, score: 48
# Scores: (min: 9, avg: 137.725, max: 347)
#
# Run: 81, exploration: 0.01, score: 13
# Scores: (min: 9, avg: 136.1851851851852, max: 347)
#
# Run: 82, exploration: 0.01, score: 175
# Scores: (min: 9, avg: 136.65853658536585, max: 347)
#
# Run: 83, exploration: 0.01, score: 164
# Scores: (min: 9, avg: 136.9879518072289, max: 347)
#
# Run: 84, exploration: 0.01, score: 207
# Scores: (min: 9, avg: 137.82142857142858, max: 347)
#
# Run: 85, exploration: 0.01, score: 200
# Scores: (min: 9, avg: 138.5529411764706, max: 347)
#
# Run: 86, exploration: 0.01, score: 214
# Scores: (min: 9, avg: 139.43023255813952, max: 347)
#
# Run: 87, exploration: 0.01, score: 162
# Scores: (min: 9, avg: 139.68965517241378, max: 347)
#
# Run: 88, exploration: 0.01, score: 226
# Scores: (min: 9, avg: 140.67045454545453, max: 347)
#
# Run: 89, exploration: 0.01, score: 147
# Scores: (min: 9, avg: 140.74157303370785, max: 347)
#
# Run: 90, exploration: 0.01, score: 144
# Scores: (min: 9, avg: 140.77777777777777, max: 347)
# Run: 91, exploration: 0.01, score: 101
# Scores: (min: 9, avg: 140.34065934065933, max: 347)
#
# Run: 92, exploration: 0.01, score: 255
# Scores: (min: 9, avg: 141.58695652173913, max: 347)
#
# Run: 93, exploration: 0.01, score: 197
# Scores: (min: 9, avg: 142.18279569892474, max: 347)
#
# Run: 94, exploration: 0.01, score: 101
# Scores: (min: 9, avg: 141.74468085106383, max: 347)
#
# Run: 95, exploration: 0.01, score: 205
# Scores: (min: 9, avg: 142.41052631578947, max: 347)
#
# Run: 96, exploration: 0.01, score: 215
# Scores: (min: 9, avg: 143.16666666666666, max: 347)
#
# Run: 97, exploration: 0.01, score: 177
# Scores: (min: 9, avg: 143.51546391752578, max: 347)
#
# Run: 98, exploration: 0.01, score: 120
# Scores: (min: 9, avg: 143.27551020408163, max: 347)
#
# Run: 99, exploration: 0.01, score: 286
# Scores: (min: 9, avg: 144.7171717171717, max: 347)
#
# Run: 100, exploration: 0.01, score: 168
# Scores: (min: 9, avg: 144.95, max: 347)
#
# Run: 101, exploration: 0.01, score: 199
# Scores: (min: 9, avg: 146.84, max: 347)
#
# Run: 102, exploration: 0.01, score: 289
# Scores: (min: 9, avg: 149.55, max: 347)
#
# Run: 103, exploration: 0.01, score: 171
# Scores: (min: 9, avg: 151.14, max: 347)
#
# Run: 104, exploration: 0.01, score: 114
# Scores: (min: 9, avg: 152.1, max: 347)
#
# Run: 105, exploration: 0.01, score: 107
# Scores: (min: 9, avg: 152.84, max: 347)
#
# Run: 106, exploration: 0.01, score: 172
# Scores: (min: 9, avg: 154.36, max: 347)
#
# Run: 107, exploration: 0.01, score: 183
# Scores: (min: 9, avg: 156.1, max: 347)
#
# Run: 108, exploration: 0.01, score: 189
# Scores: (min: 11, avg: 157.9, max: 347)
#
# Run: 109, exploration: 0.01, score: 133
# Scores: (min: 13, avg: 159.12, max: 347)
#
# Run: 110, exploration: 0.01, score: 132
# Scores: (min: 13, avg: 160.29, max: 347)
#
# Run: 111, exploration: 0.01, score: 274
# Scores: (min: 13, avg: 162.88, max: 347)
#
# Run: 112, exploration: 0.01, score: 261
# Scores: (min: 13, avg: 164.9, max: 347)
#
# Run: 113, exploration: 0.01, score: 388
# Scores: (min: 13, avg: 168.48, max: 388)
#
# Run: 114, exploration: 0.01, score: 104
# Scores: (min: 13, avg: 168.92, max: 388)
#
# Run: 115, exploration: 0.01, score: 170
# Scores: (min: 13, avg: 169.95, max: 388)
#
# Run: 116, exploration: 0.01, score: 143
# Scores: (min: 13, avg: 170.88, max: 388)
#
# Run: 117, exploration: 0.01, score: 275
# Scores: (min: 13, avg: 173.27, max: 388)
#
# Run: 118, exploration: 0.01, score: 148
# Scores: (min: 13, avg: 174.16, max: 388)
#
# Run: 119, exploration: 0.01, score: 88
# Scores: (min: 13, avg: 173.94, max: 388)
#
# Run: 120, exploration: 0.01, score: 190
# Scores: (min: 13, avg: 174.67, max: 388)
#
# Run: 121, exploration: 0.01, score: 190
# Scores: (min: 13, avg: 176.35, max: 388)
#
# Run: 122, exploration: 0.01, score: 136
# Scores: (min: 13, avg: 176.95, max: 388)
#
# Run: 123, exploration: 0.01, score: 174
# Scores: (min: 13, avg: 177.57, max: 388)
#
# Run: 124, exploration: 0.01, score: 181
# Scores: (min: 13, avg: 177.03, max: 388)
#
# Run: 125, exploration: 0.01, score: 188
# Scores: (min: 13, avg: 176.93, max: 388)
#
# Run: 126, exploration: 0.01, score: 176
# Scores: (min: 13, avg: 176.93, max: 388)
#
# Run: 127, exploration: 0.01, score: 125
# Scores: (min: 13, avg: 175.56, max: 388)
#
# Run: 128, exploration: 0.01, score: 87
# Scores: (min: 13, avg: 174.8, max: 388)
#
# Run: 129, exploration: 0.01, score: 197
# Scores: (min: 13, avg: 173.3, max: 388)
#
# Run: 130, exploration: 0.01, score: 213
# Scores: (min: 13, avg: 173.8, max: 388)
#
# Run: 131, exploration: 0.01, score: 153
# Scores: (min: 13, avg: 173.7, max: 388)
#
# Run: 132, exploration: 0.01, score: 361
# Scores: (min: 13, avg: 175.63, max: 388)
#
# Run: 133, exploration: 0.01, score: 162
# Scores: (min: 13, avg: 175.37, max: 388)
#
# Run: 134, exploration: 0.01, score: 225
# Scores: (min: 13, avg: 176.09, max: 388)
#
# Run: 135, exploration: 0.01, score: 189
# Scores: (min: 13, avg: 176.61, max: 388)
#
# Run: 136, exploration: 0.01, score: 16
# Scores: (min: 13, avg: 175.51, max: 388)
#
# Run: 137, exploration: 0.01, score: 203
# Scores: (min: 13, avg: 175.3, max: 388)
#
# Run: 138, exploration: 0.01, score: 168
# Scores: (min: 13, avg: 174.09, max: 388)
#
# Run: 139, exploration: 0.01, score: 331
# Scores: (min: 13, avg: 175.69, max: 388)
#
# Run: 140, exploration: 0.01, score: 168
# Scores: (min: 13, avg: 175.92, max: 388)
#
# Run: 141, exploration: 0.01, score: 158
# Scores: (min: 13, avg: 175.81, max: 388)
#
# Run: 142, exploration: 0.01, score: 109
# Scores: (min: 13, avg: 174.16, max: 388)
#
# Run: 143, exploration: 0.01, score: 151
# Scores: (min: 13, avg: 173.28, max: 388)
#
# Run: 144, exploration: 0.01, score: 167
# Scores: (min: 13, avg: 173.17, max: 388)
#
# Run: 145, exploration: 0.01, score: 155
# Scores: (min: 13, avg: 173.05, max: 388)
#
# Run: 146, exploration: 0.01, score: 167
# Scores: (min: 13, avg: 172.66, max: 388)
#
# Run: 147, exploration: 0.01, score: 410
# Scores: (min: 13, avg: 175.02, max: 410)
#
# Run: 148, exploration: 0.01, score: 117
# Scores: (min: 13, avg: 174.16, max: 410)
#
# Run: 149, exploration: 0.01, score: 111
# Scores: (min: 13, avg: 173.1, max: 410)
#
# Run: 150, exploration: 0.01, score: 151
# Scores: (min: 13, avg: 173.12, max: 410)
#
# Run: 151, exploration: 0.01, score: 110
# Scores: (min: 13, avg: 172.58, max: 410)
#
# Run: 152, exploration: 0.01, score: 101
# Scores: (min: 13, avg: 171.68, max: 410)
#
# Run: 153, exploration: 0.01, score: 76
# Scores: (min: 13, avg: 170.55, max: 410)
#
# Run: 154, exploration: 0.01, score: 125
# Scores: (min: 13, avg: 170.02, max: 410)
#
# Run: 155, exploration: 0.01, score: 110
# Scores: (min: 13, avg: 169.42, max: 410)
#
# Run: 156, exploration: 0.01, score: 196
# Scores: (min: 13, avg: 168.65, max: 410)
#
# Run: 157, exploration: 0.01, score: 347
# Scores: (min: 13, avg: 170.76, max: 410)
#
# Run: 158, exploration: 0.01, score: 120
# Scores: (min: 13, avg: 170.16, max: 410)
#
# Run: 159, exploration: 0.01, score: 17
# Scores: (min: 13, avg: 169.09, max: 410)
#
# Run: 160, exploration: 0.01, score: 121
# Scores: (min: 13, avg: 168.85, max: 410)
#
# Run: 161, exploration: 0.01, score: 339
# Scores: (min: 13, avg: 170.9, max: 410)
#
# Run: 162, exploration: 0.01, score: 85
# Scores: (min: 13, avg: 171.12, max: 410)
#
# Run: 163, exploration: 0.01, score: 65
# Scores: (min: 13, avg: 170.21, max: 410)
#
# Run: 164, exploration: 0.01, score: 70
# Scores: (min: 13, avg: 168.96, max: 410)
#
# Run: 165, exploration: 0.01, score: 10
# Scores: (min: 10, avg: 167.35, max: 410)
#
# Run: 166, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 165.95, max: 410)
#
# Run: 167, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 163.77, max: 410)
#
# Run: 168, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 162.3, max: 410)
#
# Run: 169, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 160.77, max: 410)
#
# Run: 170, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 159.44, max: 410)
#
# Run: 171, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 157.86, max: 410)
#
# Run: 172, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 156.49, max: 410)
#
# Run: 173, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 155.05, max: 410)
#
# Run: 174, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 153.62, max: 410)
#
# Run: 175, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 152.35, max: 410)
#
# Run: 176, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 150.8, max: 410)
#
# Run: 177, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 148.68, max: 410)
#
# Run: 178, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 146.44, max: 410)
#
# Run: 179, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 146.23, max: 410)
#
# Run: 180, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 145.85, max: 410)
#
# Run: 181, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 145.82, max: 410)
#
# Run: 182, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 144.16, max: 410)
#
# Run: 183, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 142.62, max: 410)
#
# Run: 184, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 140.65, max: 410)
#
# Run: 185, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 138.74, max: 410)
#
# Run: 186, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 136.69, max: 410)
#
# Run: 187, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 135.17, max: 410)
#
# Run: 188, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 133.02, max: 410)
#
# Run: 189, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 131.64, max: 410)
#
# Run: 190, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 130.29, max: 410)
# Run: 191, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 129.38, max: 410)
#
# Run: 192, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 126.91, max: 410)
#
# Run: 193, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 125.04, max: 410)
#
# Run: 194, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 124.13, max: 410)
#
# Run: 195, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 122.18, max: 410)
#
# Run: 196, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 120.13, max: 410)
#
# Run: 197, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 118.45, max: 410)
#
# Run: 198, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 117.35, max: 410)
#
# Run: 199, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 114.58, max: 410)
#
# Run: 200, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 112.99, max: 410)
#
# Run: 201, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 111.09, max: 410)
#
# Run: 202, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 108.29, max: 410)
#
# Run: 203, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 106.67, max: 410)
#
# Run: 204, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 105.61, max: 410)
#
# Run: 205, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 104.64, max: 410)
#
# Run: 206, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 103.01, max: 410)
#
# Run: 207, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 101.28, max: 410)
#
# Run: 208, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 99.48, max: 410)
#
# Run: 209, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 98.25, max: 410)
#
# Run: 210, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 97.01, max: 410)
#
# Run: 211, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 94.37, max: 410)
#
# Run: 212, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 91.86, max: 410)
#
# Run: 213, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 88.07, max: 410)
#
# Run: 214, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 87.13, max: 410)
#
# Run: 215, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 85.53, max: 410)
#
# Run: 216, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 84.2, max: 410)
#
# Run: 217, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 81.54, max: 410)
#
# Run: 218, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 80.16, max: 410)
#
# Run: 219, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 79.38, max: 410)
#
# Run: 220, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 77.57, max: 410)
#
# Run: 221, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 75.77, max: 410)
#
# Run: 222, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 74.51, max: 410)
#
# Run: 223, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 72.87, max: 410)
#
# Run: 224, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 71.15, max: 410)
#
# Run: 225, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 69.38, max: 410)
#
# Run: 226, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 67.71, max: 410)
#
# Run: 227, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 66.55, max: 410)
#
# Run: 228, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 65.77, max: 410)
#
# Run: 229, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 63.9, max: 410)
#
# Run: 230, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 61.86, max: 410)
#
# Run: 231, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 60.43, max: 410)
#
# Run: 232, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 56.92, max: 410)
#
# Run: 233, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 55.38, max: 410)
#
# Run: 234, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 53.23, max: 410)
#
# Run: 235, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 51.44, max: 410)
#
# Run: 236, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 51.38, max: 410)
#
# Run: 237, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 49.47, max: 410)
#
# Run: 238, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 47.93, max: 410)
#
# Run: 239, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 44.74, max: 410)
#
# Run: 240, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 43.27, max: 410)
#
# Run: 241, exploration: 0.01, score: 39
# Scores: (min: 8, avg: 42.08, max: 410)
#
# Run: 242, exploration: 0.01, score: 69
# Scores: (min: 8, avg: 41.68, max: 410)
#
# Run: 243, exploration: 0.01, score: 83
# Scores: (min: 8, avg: 41, max: 410)
#
# Run: 244, exploration: 0.01, score: 75
# Scores: (min: 8, avg: 40.08, max: 410)
#
# Run: 245, exploration: 0.01, score: 115
# Scores: (min: 8, avg: 39.68, max: 410)
#
# Run: 246, exploration: 0.01, score: 164
# Scores: (min: 8, avg: 39.65, max: 410)
#
# Run: 247, exploration: 0.01, score: 168
# Scores: (min: 8, avg: 37.23, max: 347)
#
# Run: 248, exploration: 0.01, score: 136
# Scores: (min: 8, avg: 37.42, max: 347)
#
# Run: 249, exploration: 0.01, score: 280
# Scores: (min: 8, avg: 39.11, max: 347)
#
# Run: 250, exploration: 0.01, score: 51
# Scores: (min: 8, avg: 38.11, max: 347)
#
# Run: 251, exploration: 0.01, score: 117
# Scores: (min: 8, avg: 38.18, max: 347)
#
# Run: 252, exploration: 0.01, score: 162
# Scores: (min: 8, avg: 38.79, max: 347)
#
# Run: 253, exploration: 0.01, score: 161
# Scores: (min: 8, avg: 39.64, max: 347)
#
# Run: 254, exploration: 0.01, score: 152
# Scores: (min: 8, avg: 39.91, max: 347)
#
# Run: 255, exploration: 0.01, score: 171
# Scores: (min: 8, avg: 40.52, max: 347)
#
# Run: 256, exploration: 0.01, score: 111
# Scores: (min: 8, avg: 39.67, max: 347)
#
# Run: 257, exploration: 0.01, score: 87
# Scores: (min: 8, avg: 37.07, max: 339)
#
# Run: 258, exploration: 0.01, score: 152
# Scores: (min: 8, avg: 37.39, max: 339)
#
# Run: 259, exploration: 0.01, score: 235
# Scores: (min: 8, avg: 39.57, max: 339)
#
# Run: 260, exploration: 0.01, score: 192
# Scores: (min: 8, avg: 40.28, max: 339)
#
# Run: 261, exploration: 0.01, score: 153
# Scores: (min: 8, avg: 38.42, max: 280)
#
# Run: 262, exploration: 0.01, score: 162
# Scores: (min: 8, avg: 39.19, max: 280)
#
# Run: 263, exploration: 0.01, score: 231
# Scores: (min: 8, avg: 40.85, max: 280)
#
# Run: 264, exploration: 0.01, score: 104
# Scores: (min: 8, avg: 41.19, max: 280)
#
# Run: 265, exploration: 0.01, score: 176
# Scores: (min: 8, avg: 42.85, max: 280)
#
# Run: 266, exploration: 0.01, score: 263
# Scores: (min: 8, avg: 45.39, max: 280)
#
# Run: 267, exploration: 0.01, score: 197
# Scores: (min: 8, avg: 47.26, max: 280)
#
# Run: 268, exploration: 0.01, score: 225
# Scores: (min: 8, avg: 49.41, max: 280)
#
# Run: 269, exploration: 0.01, score: 242
# Scores: (min: 8, avg: 51.73, max: 280)
#
# Run: 270, exploration: 0.01, score: 206
# Scores: (min: 8, avg: 53.71, max: 280)
#
# Run: 271, exploration: 0.01, score: 169
# Scores: (min: 8, avg: 55.3, max: 280)
#
# Run: 272, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 60.2, max: 500)
#
# Run: 273, exploration: 0.01, score: 192
# Scores: (min: 8, avg: 62.02, max: 500)
#
# Run: 274, exploration: 0.01, score: 242
# Scores: (min: 8, avg: 64.34, max: 500)
#
# Run: 275, exploration: 0.01, score: 269
# Scores: (min: 8, avg: 66.93, max: 500)
#
# Run: 276, exploration: 0.01, score: 251
# Scores: (min: 8, avg: 69.33, max: 500)
#
# Run: 277, exploration: 0.01, score: 215
# Scores: (min: 8, avg: 71.38, max: 500)
#
# Run: 278, exploration: 0.01, score: 221
# Scores: (min: 8, avg: 73.5, max: 500)
#
# Run: 279, exploration: 0.01, score: 281
# Scores: (min: 8, avg: 76.21, max: 500)
#
# Run: 280, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 76.22, max: 500)
#
# Run: 281, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 76.22, max: 500)
#
# Run: 282, exploration: 0.01, score: 101
# Scores: (min: 8, avg: 77.14, max: 500)
#
# Run: 283, exploration: 0.01, score: 251
# Scores: (min: 8, avg: 79.55, max: 500)
#
# Run: 284, exploration: 0.01, score: 309
# Scores: (min: 8, avg: 82.54, max: 500)
#
# Run: 285, exploration: 0.01, score: 262
# Scores: (min: 8, avg: 85.07, max: 500)
#
# Run: 286, exploration: 0.01, score: 361
# Scores: (min: 8, avg: 88.59, max: 500)
#
# Run: 287, exploration: 0.01, score: 207
# Scores: (min: 8, avg: 90.56, max: 500)
#
# Run: 288, exploration: 0.01, score: 194
# Scores: (min: 8, avg: 92.39, max: 500)
#
# Run: 289, exploration: 0.01, score: 38
# Scores: (min: 8, avg: 92.68, max: 500)
#
# Run: 290, exploration: 0.01, score: 145
# Scores: (min: 8, avg: 94.04, max: 500)
#
# Run: 291, exploration: 0.01, score: 151
# Scores: (min: 8, avg: 95.45, max: 500)
#
# Run: 292, exploration: 0.01, score: 400
# Scores: (min: 8, avg: 99.37, max: 500)
#
# Run: 293, exploration: 0.01, score: 206
# Scores: (min: 8, avg: 101.33, max: 500)
#
# Run: 294, exploration: 0.01, score: 211
# Scores: (min: 8, avg: 103.34, max: 500)
# Run: 295, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 108.24, max: 500)
#
# Run: 296, exploration: 0.01, score: 53
# Scores: (min: 8, avg: 108.67, max: 500)
#
# Run: 297, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 108.67, max: 500)
#
# Run: 298, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 108.67, max: 500)
#
# Run: 299, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 108.68, max: 500)
#
# Run: 300, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 108.69, max: 500)
#
# Run: 301, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 108.68, max: 500)
#
# Run: 302, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 108.69, max: 500)
#
# Run: 303, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 108.7, max: 500)
#
# Run: 304, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 108.71, max: 500)
#
# Run: 305, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 108.7, max: 500)
#
# Run: 306, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 108.72, max: 500)
#
# Run: 307, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 108.71, max: 500)
#
# Run: 308, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 108.72, max: 500)
#
# Run: 309, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 108.7, max: 500)
#
# Run: 310, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 108.71, max: 500)
#
# Run: 311, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 108.71, max: 500)
#
# Run: 312, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 108.74, max: 500)
#
# Run: 313, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 108.77, max: 500)
#
# Run: 314, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 109.11, max: 500)
#
# Run: 315, exploration: 0.01, score: 60
# Scores: (min: 8, avg: 109.61, max: 500)
#
# Run: 316, exploration: 0.01, score: 101
# Scores: (min: 8, avg: 110.52, max: 500)
#
# Run: 317, exploration: 0.01, score: 480
# Scores: (min: 8, avg: 115.23, max: 500)
#
# Run: 318, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 115.29, max: 500)
#
# Run: 319, exploration: 0.01, score: 108
# Scores: (min: 8, avg: 116.27, max: 500)
#
# Run: 320, exploration: 0.01, score: 162
# Scores: (min: 8, avg: 117.8, max: 500)
#
# Run: 321, exploration: 0.01, score: 268
# Scores: (min: 8, avg: 120.38, max: 500)
#
# Run: 322, exploration: 0.01, score: 175
# Scores: (min: 8, avg: 122.03, max: 500)
#
# Run: 323, exploration: 0.01, score: 73
# Scores: (min: 8, avg: 122.66, max: 500)
#
# Run: 324, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 122.66, max: 500)
#
# Run: 325, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 122.64, max: 500)
#
# Run: 326, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 122.64, max: 500)
#
# Run: 327, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 122.64, max: 500)
#
# Run: 328, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 122.63, max: 500)
#
# Run: 329, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 122.64, max: 500)
#
# Run: 330, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 122.64, max: 500)
#
# Run: 331, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 122.63, max: 500)
#
# Run: 332, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 122.62, max: 500)
#
# Run: 333, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 122.63, max: 500)
#
# Run: 334, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 122.63, max: 500)
#
# Run: 335, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 122.62, max: 500)
#
# Run: 336, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 122.61, max: 500)
#
# Run: 337, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 122.59, max: 500)
#
# Run: 338, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 122.54, max: 500)
#
# Run: 339, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 122.52, max: 500)
#
# Run: 340, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 122.61, max: 500)
#
# Run: 341, exploration: 0.01, score: 45
# Scores: (min: 8, avg: 122.67, max: 500)
#
# Run: 342, exploration: 0.01, score: 40
# Scores: (min: 8, avg: 122.38, max: 500)
#
# Run: 343, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 121.86, max: 500)
#
# Run: 344, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 121.28, max: 500)
#
# Run: 345, exploration: 0.01, score: 152
# Scores: (min: 8, avg: 121.65, max: 500)
#
# Run: 346, exploration: 0.01, score: 147
# Scores: (min: 8, avg: 121.48, max: 500)
#
# Run: 347, exploration: 0.01, score: 40
# Scores: (min: 8, avg: 120.2, max: 500)
#
# Run: 348, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 119.18, max: 500)
#
# Run: 349, exploration: 0.01, score: 48
# Scores: (min: 8, avg: 116.86, max: 500)
#
# Run: 350, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 116.63, max: 500)
#
# Run: 351, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 115.66, max: 500)
#
# Run: 352, exploration: 0.01, score: 52
# Scores: (min: 8, avg: 114.56, max: 500)
#
# Run: 353, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 113.07, max: 500)
#
# Run: 354, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 111.68, max: 500)
#
# Run: 355, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 110.09, max: 500)
#
# Run: 356, exploration: 0.01, score: 105
# Scores: (min: 8, avg: 110.03, max: 500)
#
# Run: 357, exploration: 0.01, score: 60
# Scores: (min: 8, avg: 109.76, max: 500)
#
# Run: 358, exploration: 0.01, score: 178
# Scores: (min: 8, avg: 110.02, max: 500)
#
# Run: 359, exploration: 0.01, score: 124
# Scores: (min: 8, avg: 108.91, max: 500)
#
# Run: 360, exploration: 0.01, score: 169
# Scores: (min: 8, avg: 108.68, max: 500)
#
# Run: 361, exploration: 0.01, score: 171
# Scores: (min: 8, avg: 108.86, max: 500)
#
# Run: 362, exploration: 0.01, score: 124
# Scores: (min: 8, avg: 108.48, max: 500)
#
# Run: 363, exploration: 0.01, score: 162
# Scores: (min: 8, avg: 107.79, max: 500)
#
# Run: 364, exploration: 0.01, score: 155
# Scores: (min: 8, avg: 108.3, max: 500)
#
# Run: 365, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 106.64, max: 500)
#
# Run: 366, exploration: 0.01, score: 149
# Scores: (min: 8, avg: 105.5, max: 500)
#
# Run: 367, exploration: 0.01, score: 237
# Scores: (min: 8, avg: 105.9, max: 500)
#
# Run: 368, exploration: 0.01, score: 173
# Scores: (min: 8, avg: 105.38, max: 500)
#
# Run: 369, exploration: 0.01, score: 387
# Scores: (min: 8, avg: 106.83, max: 500)
#
# Run: 370, exploration: 0.01, score: 201
# Scores: (min: 8, avg: 106.78, max: 500)
#
# Run: 371, exploration: 0.01, score: 204
# Scores: (min: 8, avg: 107.13, max: 500)
#
# Run: 372, exploration: 0.01, score: 217
# Scores: (min: 8, avg: 104.3, max: 500)
#
# Run: 373, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 102.54, max: 500)
#
# Run: 374, exploration: 0.01, score: 258
# Scores: (min: 8, avg: 102.7, max: 500)
#
# Run: 375, exploration: 0.01, score: 239
# Scores: (min: 8, avg: 102.4, max: 500)
#
# Run: 376, exploration: 0.01, score: 171
# Scores: (min: 8, avg: 101.6, max: 500)
#
# Run: 377, exploration: 0.01, score: 257
# Scores: (min: 8, avg: 102.02, max: 500)
#
# Run: 378, exploration: 0.01, score: 230
# Scores: (min: 8, avg: 102.11, max: 500)
#
# Run: 379, exploration: 0.01, score: 190
# Scores: (min: 8, avg: 101.2, max: 500)
#
# Run: 380, exploration: 0.01, score: 305
# Scores: (min: 8, avg: 104.14, max: 500)
#
# Run: 381, exploration: 0.01, score: 120
# Scores: (min: 8, avg: 105.24, max: 500)
#
# Run: 382, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 104.33, max: 500)
#
# Run: 383, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 101.9, max: 500)
#
# Run: 384, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 98.9, max: 500)
#
# Run: 385, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 96.37, max: 500)
#
# Run: 386, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 92.85, max: 500)
#
# Run: 387, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 90.88, max: 500)
#
# Run: 388, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 89.05, max: 500)
#
# Run: 389, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 88.76, max: 500)
#
# Run: 390, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 87.39, max: 500)
#
# Run: 391, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 85.98, max: 500)
#
# Run: 392, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 82.08, max: 500)
#
# Run: 393, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 80.11, max: 500)
#
# Run: 394, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 78.09, max: 500)
#
# Run: 395, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 73.17, max: 480)
#
# Run: 396, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 72.73, max: 480)
#
# Run: 397, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 72.73, max: 480)
# Run: 398, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 72.72, max: 480)
#
# Run: 399, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 72.71, max: 480)
#
# Run: 400, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 72.69, max: 480)
#
# Run: 401, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 72.71, max: 480)
#
# Run: 402, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 72.7, max: 480)
#
# Run: 403, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 72.71, max: 480)
#
# Run: 404, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 72.76, max: 480)
#
# Run: 405, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 72.81, max: 480)
#
# Run: 406, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 72.97, max: 480)
#
# Run: 407, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 73.11, max: 480)
#
# Run: 408, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 73.29, max: 480)
#
# Run: 409, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 73.5, max: 480)
#
# Run: 410, exploration: 0.01, score: 164
# Scores: (min: 8, avg: 75.05, max: 480)
#
# Run: 411, exploration: 0.01, score: 485
# Scores: (min: 8, avg: 79.8, max: 485)
#
# Run: 412, exploration: 0.01, score: 293
# Scores: (min: 8, avg: 82.6, max: 485)
#
# Run: 413, exploration: 0.01, score: 280
# Scores: (min: 8, avg: 85.28, max: 485)
#
# Run: 414, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 89.84, max: 500)
#
# Run: 415, exploration: 0.01, score: 409
# Scores: (min: 8, avg: 93.33, max: 500)
#
# Run: 416, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 97.32, max: 500)
#
# Run: 417, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 97.52, max: 500)
#
# Run: 418, exploration: 0.01, score: 387
# Scores: (min: 8, avg: 101.23, max: 500)
#
# Run: 419, exploration: 0.01, score: 222
# Scores: (min: 8, avg: 102.37, max: 500)
#
# Run: 420, exploration: 0.01, score: 326
# Scores: (min: 8, avg: 104.01, max: 500)
#
# Run: 421, exploration: 0.01, score: 447
# Scores: (min: 8, avg: 105.8, max: 500)
#
# Run: 422, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 109.05, max: 500)
#
# Run: 423, exploration: 0.01, score: 312
# Scores: (min: 8, avg: 111.44, max: 500)
#
# Run: 424, exploration: 0.01, score: 259
# Scores: (min: 8, avg: 113.94, max: 500)
#
# Run: 425, exploration: 0.01, score: 239
# Scores: (min: 8, avg: 116.24, max: 500)
#
# Run: 426, exploration: 0.01, score: 473
# Scores: (min: 8, avg: 120.88, max: 500)
#
# Run: 427, exploration: 0.01, score: 360
# Scores: (min: 8, avg: 124.39, max: 500)
#
# Run: 428, exploration: 0.01, score: 289
# Scores: (min: 8, avg: 127.2, max: 500)
#
# Run: 429, exploration: 0.01, score: 283
# Scores: (min: 8, avg: 129.92, max: 500)
#
# Run: 430, exploration: 0.01, score: 339
# Scores: (min: 8, avg: 133.22, max: 500)
#
# Run: 431, exploration: 0.01, score: 254
# Scores: (min: 8, avg: 135.67, max: 500)
#
# Run: 432, exploration: 0.01, score: 49
# Scores: (min: 8, avg: 136.07, max: 500)
#
# Run: 433, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 136.07, max: 500)
#
# Run: 434, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 136.06, max: 500)
#
# Run: 435, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 136.06, max: 500)
#
# Run: 436, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 136.07, max: 500)
#
# Run: 437, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 136.06, max: 500)
#
# Run: 438, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 136.07, max: 500)
#
# Run: 439, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 136.06, max: 500)
#
# Run: 440, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 135.85, max: 500)
#
# Run: 441, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 135.5, max: 500)
#
# Run: 442, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 135.2, max: 500)
#
# Run: 443, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 134.97, max: 500)
#
# Run: 444, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 134.89, max: 500)
#
# Run: 445, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 133.46, max: 500)
#
# Run: 446, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 132.08, max: 500)
#
# Run: 447, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 131.77, max: 500)
#
# Run: 448, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 131.51, max: 500)
#
# Run: 449, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 131.11, max: 500)
#
# Run: 450, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 130.92, max: 500)
#
# Run: 451, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 130.82, max: 500)
#
# Run: 452, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 130.38, max: 500)
#
# Run: 453, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 130.36, max: 500)
#
# Run: 454, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 130.32, max: 500)
#
# Run: 455, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 130.29, max: 500)
#
# Run: 456, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 129.32, max: 500)
#
# Run: 457, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 128.81, max: 500)
#
# Run: 458, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 127.11, max: 500)
#
# Run: 459, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 125.96, max: 500)
#
# Run: 460, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 124.37, max: 500)
#
# Run: 461, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 122.76, max: 500)
#
# Run: 462, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 121.62, max: 500)
#
# Run: 463, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 120.09, max: 500)
#
# Run: 464, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 118.63, max: 500)
#
# Run: 465, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 118.61, max: 500)
#
# Run: 466, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 117.23, max: 500)
#
# Run: 467, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 114.97, max: 500)
#
# Run: 468, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 113.33, max: 500)
#
# Run: 469, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 109.55, max: 500)
#
# Run: 470, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 107.63, max: 500)
#
# Run: 471, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 105.68, max: 500)
#
# Run: 472, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 103.6, max: 500)
#
# Run: 473, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 103.53, max: 500)
#
# Run: 474, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 101.05, max: 500)
#
# Run: 475, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 98.75, max: 500)
#
# Run: 476, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 97.13, max: 500)
#
# Run: 477, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 94.65, max: 500)
#
# Run: 478, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 92.44, max: 500)
#
# Run: 479, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 90.63, max: 500)
#
# Run: 480, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 87.67, max: 500)
#
# Run: 481, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 86.56, max: 500)
#
# Run: 482, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 86.56, max: 500)
#
# Run: 483, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 86.58, max: 500)
#
# Run: 484, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 86.57, max: 500)
#
# Run: 485, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 86.57, max: 500)
#
# Run: 486, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 86.58, max: 500)
#
# Run: 487, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 86.56, max: 500)
#
# Run: 488, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 86.53, max: 500)
#
# Run: 489, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 86.52, max: 500)
#
# Run: 490, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 86.55, max: 500)
#
# Run: 491, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 86.56, max: 500)
#
# Run: 492, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 86.55, max: 500)
#
# Run: 493, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 86.57, max: 500)
#
# Run: 494, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 86.59, max: 500)
#
# Run: 495, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 86.71, max: 500)
#
# Run: 496, exploration: 0.01, score: 42
# Scores: (min: 8, avg: 87.04, max: 500)
#
# Run: 497, exploration: 0.01, score: 67
# Scores: (min: 8, avg: 87.62, max: 500)
#
# Run: 498, exploration: 0.01, score: 68
# Scores: (min: 8, avg: 88.21, max: 500)
#
# Run: 499, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 88.45, max: 500)
#
# Run: 500, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 88.46, max: 500)
#
# Run: 501, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 88.45, max: 500)
# Run: 502, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 88.45, max: 500)
#
# Run: 503, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 88.43, max: 500)
#
# Run: 504, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 88.39, max: 500)
#
# Run: 505, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 88.34, max: 500)
#
# Run: 506, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 88.17, max: 500)
#
# Run: 507, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 88.03, max: 500)
#
# Run: 508, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 87.84, max: 500)
#
# Run: 509, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 87.64, max: 500)
#
# Run: 510, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 86.08, max: 500)
#
# Run: 511, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 81.32, max: 500)
#
# Run: 512, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 78.49, max: 500)
#
# Run: 513, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 75.78, max: 500)
#
# Run: 514, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 70.88, max: 500)
#
# Run: 515, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 66.89, max: 500)
#
# Run: 516, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 61.99, max: 500)
#
# Run: 517, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 57.08, max: 500)
#
# Run: 518, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 53.29, max: 500)
#
# Run: 519, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 51.16, max: 500)
#
# Run: 520, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 47.99, max: 500)
#
# Run: 521, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 43.6, max: 500)
#
# Run: 522, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 38.7, max: 473)
#
# Run: 523, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 35.68, max: 473)
#
# Run: 524, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 33.18, max: 473)
#
# Run: 525, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 30.89, max: 473)
#
# Run: 526, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 26.25, max: 360)
#
# Run: 527, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 22.74, max: 339)
#
# Run: 528, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 19.94, max: 339)
#
# Run: 529, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 17.2, max: 339)
#
# Run: 530, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 13.89, max: 254)
#
# Run: 531, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.44, max: 68)
#
# Run: 532, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.05, max: 68)
#
# Run: 533, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.05, max: 68)
#
# Run: 534, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 11.04, max: 68)
#
# Run: 535, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.05, max: 68)
#
# Run: 536, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.05, max: 68)
#
# Run: 537, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.06, max: 68)
#
# Run: 538, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.06, max: 68)
#
# Run: 539, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 11.1, max: 68)
#
# Run: 540, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.11, max: 68)
#
# Run: 541, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.11, max: 68)
#
# Run: 542, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.11, max: 68)
#
# Run: 543, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.12, max: 68)
#
# Run: 544, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.13, max: 68)
#
# Run: 545, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 11.3, max: 68)
#
# Run: 546, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 11.52, max: 68)
#
# Run: 547, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 11.58, max: 68)
#
# Run: 548, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 11.82, max: 68)
#
# Run: 549, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 11.99, max: 68)
#
# Run: 550, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.01, max: 68)
#
# Run: 551, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 12.19, max: 68)
#
# Run: 552, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 12.27, max: 68)
#
# Run: 553, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 12.45, max: 68)
#
# Run: 554, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 12.69, max: 68)
#
# Run: 555, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 12.85, max: 68)
#
# Run: 556, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.87, max: 68)
#
# Run: 557, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 12.9, max: 68)
#
# Run: 558, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 12.98, max: 68)
#
# Run: 559, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 13.01, max: 68)
#
# Run: 560, exploration: 0.01, score: 48
# Scores: (min: 8, avg: 13.39, max: 68)
#
# Run: 561, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.39, max: 68)
#
# Run: 562, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.39, max: 68)
#
# Run: 563, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.4, max: 68)
#
# Run: 564, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 13.62, max: 68)
#
# Run: 565, exploration: 0.01, score: 81
# Scores: (min: 8, avg: 14.35, max: 81)
#
# Run: 566, exploration: 0.01, score: 57
# Scores: (min: 8, avg: 14.81, max: 81)
#
# Run: 567, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 14.98, max: 81)
#
# Run: 568, exploration: 0.01, score: 97
# Scores: (min: 8, avg: 15.86, max: 97)
#
# Run: 569, exploration: 0.01, score: 76
# Scores: (min: 8, avg: 16.53, max: 97)
#
# Run: 570, exploration: 0.01, score: 42
# Scores: (min: 8, avg: 16.86, max: 97)
#
# Run: 571, exploration: 0.01, score: 41
# Scores: (min: 8, avg: 17.18, max: 97)
#
# Run: 572, exploration: 0.01, score: 78
# Scores: (min: 8, avg: 17.87, max: 97)
#
# Run: 573, exploration: 0.01, score: 139
# Scores: (min: 8, avg: 19.17, max: 139)
#
# Run: 574, exploration: 0.01, score: 133
# Scores: (min: 8, avg: 20.4, max: 139)
#
# Run: 575, exploration: 0.01, score: 61
# Scores: (min: 8, avg: 20.92, max: 139)
#
# Run: 576, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 20.98, max: 139)
#
# Run: 577, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 21, max: 139)
#
# Run: 578, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 21.01, max: 139)
#
# Run: 579, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 21.02, max: 139)
#
# Run: 580, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 21.04, max: 139)
#
# Run: 581, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 21.11, max: 139)
#
# Run: 582, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 21.19, max: 139)
#
# Run: 583, exploration: 0.01, score: 35
# Scores: (min: 8, avg: 21.44, max: 139)
#
# Run: 584, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 21.69, max: 139)
#
# Run: 585, exploration: 0.01, score: 105
# Scores: (min: 8, avg: 22.65, max: 139)
#
# Run: 586, exploration: 0.01, score: 167
# Scores: (min: 8, avg: 24.22, max: 167)
#
# Run: 587, exploration: 0.01, score: 272
# Scores: (min: 8, avg: 26.86, max: 272)
#
# Run: 588, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 26.98, max: 272)
#
# Run: 589, exploration: 0.01, score: 112
# Scores: (min: 8, avg: 28.02, max: 272)
#
# Run: 590, exploration: 0.01, score: 119
# Scores: (min: 8, avg: 29.1, max: 272)
#
# Run: 591, exploration: 0.01, score: 54
# Scores: (min: 8, avg: 29.53, max: 272)
#
# Run: 592, exploration: 0.01, score: 123
# Scores: (min: 8, avg: 30.67, max: 272)
#
# Run: 593, exploration: 0.01, score: 111
# Scores: (min: 8, avg: 31.67, max: 272)
#
# Run: 594, exploration: 0.01, score: 209
# Scores: (min: 8, avg: 33.65, max: 272)
#
# Run: 595, exploration: 0.01, score: 84
# Scores: (min: 8, avg: 34.29, max: 272)
#
# Run: 596, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 38.87, max: 500)
#
# Run: 597, exploration: 0.01, score: 189
# Scores: (min: 8, avg: 40.09, max: 500)
#
# Run: 598, exploration: 0.01, score: 233
# Scores: (min: 8, avg: 41.74, max: 500)
#
# Run: 599, exploration: 0.01, score: 259
# Scores: (min: 8, avg: 44, max: 500)
#
# Run: 600, exploration: 0.01, score: 307
# Scores: (min: 8, avg: 46.98, max: 500)
#
# Run: 601, exploration: 0.01, score: 212
# Scores: (min: 8, avg: 49.01, max: 500)
#
# Run: 602, exploration: 0.01, score: 213
# Scores: (min: 8, avg: 51.05, max: 500)
#
# Run: 603, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 51.21, max: 500)
#
# Run: 604, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 51.31, max: 500)
#
# Run: 605, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 51.44, max: 500)
#
# Run: 606, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 51.52, max: 500)
# Run: 607, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 51.58, max: 500)
#
# Run: 608, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 51.58, max: 500)
#
# Run: 609, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 51.7, max: 500)
#
# Run: 610, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 56.62, max: 500)
#
# Run: 611, exploration: 0.01, score: 263
# Scores: (min: 8, avg: 59.16, max: 500)
#
# Run: 612, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 64.06, max: 500)
#
# Run: 613, exploration: 0.01, score: 200
# Scores: (min: 8, avg: 65.97, max: 500)
#
# Run: 614, exploration: 0.01, score: 167
# Scores: (min: 8, avg: 67.54, max: 500)
#
# Run: 615, exploration: 0.01, score: 298
# Scores: (min: 8, avg: 70.42, max: 500)
#
# Run: 616, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 75.32, max: 500)
#
# Run: 617, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 80.23, max: 500)
#
# Run: 618, exploration: 0.01, score: 245
# Scores: (min: 8, avg: 82.6, max: 500)
#
# Run: 619, exploration: 0.01, score: 263
# Scores: (min: 8, avg: 85.14, max: 500)
#
# Run: 620, exploration: 0.01, score: 303
# Scores: (min: 8, avg: 88.08, max: 500)
#
# Run: 621, exploration: 0.01, score: 163
# Scores: (min: 8, avg: 89.63, max: 500)
#
# Run: 622, exploration: 0.01, score: 199
# Scores: (min: 8, avg: 91.52, max: 500)
#
# Run: 623, exploration: 0.01, score: 260
# Scores: (min: 8, avg: 94.02, max: 500)
#
# Run: 624, exploration: 0.01, score: 217
# Scores: (min: 8, avg: 96.1, max: 500)
#
# Run: 625, exploration: 0.01, score: 181
# Scores: (min: 8, avg: 97.81, max: 500)
#
# Run: 626, exploration: 0.01, score: 169
# Scores: (min: 8, avg: 99.41, max: 500)
#
# Run: 627, exploration: 0.01, score: 224
# Scores: (min: 8, avg: 101.56, max: 500)
#
# Run: 628, exploration: 0.01, score: 160
# Scores: (min: 8, avg: 103.07, max: 500)
#
# Run: 629, exploration: 0.01, score: 199
# Scores: (min: 8, avg: 104.97, max: 500)
#
# Run: 630, exploration: 0.01, score: 208
# Scores: (min: 8, avg: 106.97, max: 500)
#
# Run: 631, exploration: 0.01, score: 207
# Scores: (min: 8, avg: 108.95, max: 500)
#
# Run: 632, exploration: 0.01, score: 304
# Scores: (min: 8, avg: 111.89, max: 500)
#
# Run: 633, exploration: 0.01, score: 245
# Scores: (min: 8, avg: 114.25, max: 500)
#
# Run: 634, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 119.17, max: 500)
#
# Run: 635, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 124.07, max: 500)
#
# Run: 636, exploration: 0.01, score: 182
# Scores: (min: 9, avg: 125.79, max: 500)
#
# Run: 637, exploration: 0.01, score: 196
# Scores: (min: 9, avg: 127.65, max: 500)
#
# Run: 638, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 132.55, max: 500)
#
# Run: 639, exploration: 0.01, score: 154
# Scores: (min: 9, avg: 133.96, max: 500)
#
# Run: 640, exploration: 0.01, score: 206
# Scores: (min: 9, avg: 135.92, max: 500)
#
# Run: 641, exploration: 0.01, score: 208
# Scores: (min: 9, avg: 137.9, max: 500)
#
# Run: 642, exploration: 0.01, score: 146
# Scores: (min: 9, avg: 139.26, max: 500)
#
# Run: 643, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 144.17, max: 500)
#
# Run: 644, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 149.07, max: 500)
#
# Run: 645, exploration: 0.01, score: 173
# Scores: (min: 9, avg: 150.54, max: 500)
#
# Run: 646, exploration: 0.01, score: 174
# Scores: (min: 9, avg: 151.97, max: 500)
#
# Run: 647, exploration: 0.01, score: 108
# Scores: (min: 9, avg: 152.9, max: 500)
#
# Run: 648, exploration: 0.01, score: 498
# Scores: (min: 9, avg: 157.56, max: 500)
#
# Run: 649, exploration: 0.01, score: 294
# Scores: (min: 9, avg: 160.25, max: 500)
#
# Run: 650, exploration: 0.01, score: 223
# Scores: (min: 9, avg: 162.37, max: 500)
#
# Run: 651, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 167.09, max: 500)
#
# Run: 652, exploration: 0.01, score: 180
# Scores: (min: 9, avg: 168.73, max: 500)
#
# Run: 653, exploration: 0.01, score: 203
# Scores: (min: 9, avg: 170.48, max: 500)
#
# Run: 654, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 175.15, max: 500)
#
# Run: 655, exploration: 0.01, score: 332
# Scores: (min: 9, avg: 178.22, max: 500)
#
# Run: 656, exploration: 0.01, score: 387
# Scores: (min: 9, avg: 181.99, max: 500)
#
# Run: 657, exploration: 0.01, score: 92
# Scores: (min: 9, avg: 182.79, max: 500)
#
# Run: 658, exploration: 0.01, score: 251
# Scores: (min: 9, avg: 185.14, max: 500)
#
# Run: 659, exploration: 0.01, score: 168
# Scores: (min: 9, avg: 186.7, max: 500)
#
# Run: 660, exploration: 0.01, score: 175
# Scores: (min: 9, avg: 187.97, max: 500)
#
# Run: 661, exploration: 0.01, score: 206
# Scores: (min: 9, avg: 189.93, max: 500)
#
# Run: 662, exploration: 0.01, score: 136
# Scores: (min: 9, avg: 191.19, max: 500)
#
# Run: 663, exploration: 0.01, score: 139
# Scores: (min: 9, avg: 192.48, max: 500)
#
# Run: 664, exploration: 0.01, score: 258
# Scores: (min: 9, avg: 194.75, max: 500)
#
# Run: 665, exploration: 0.01, score: 158
# Scores: (min: 9, avg: 195.52, max: 500)
#
# Solved in 565 runs, 665 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9888\682879775.py in <module>
# ----> 1 cartpole()
#
# ~\AppData\Local\Temp\ipykernel_9888\820093950.py in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# ~\1CS-370\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.9  
LEARNING_RATE = 0.001  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()

# %%
cartpole()
# Out:
# Run: 1, exploration: 1.0, score: 17
# Scores: (min: 17, avg: 17, max: 17)
#
# Run: 2, exploration: 0.9369146928798039, score: 16
# Scores: (min: 16, avg: 16.5, max: 17)
#
# Run: 3, exploration: 0.7439808620067382, score: 47
# Scores: (min: 16, avg: 26.666666666666668, max: 47)
#
# Run: 4, exploration: 0.6832098777212641, score: 18
# Scores: (min: 16, avg: 24.5, max: 47)
#
# Run: 5, exploration: 0.5937455908197752, score: 29
# Scores: (min: 16, avg: 25.4, max: 47)
#
# Run: 6, exploration: 0.5371084840724134, score: 21
# Scores: (min: 16, avg: 24.666666666666668, max: 47)
#
# Run: 7, exploration: 0.5082950737585841, score: 12
# Scores: (min: 12, avg: 22.857142857142858, max: 47)
#
# Run: 8, exploration: 0.47622912292284103, score: 14
# Scores: (min: 12, avg: 21.75, max: 47)
#
# Run: 9, exploration: 0.446186062443672, score: 14
# Scores: (min: 12, avg: 20.88888888888889, max: 47)
#
# Run: 10, exploration: 0.4222502236424958, score: 12
# Scores: (min: 12, avg: 20, max: 47)
#
# Run: 11, exploration: 0.4036245882390106, score: 10
# Scores: (min: 10, avg: 19.09090909090909, max: 47)
#
# Run: 12, exploration: 0.3858205374665315, score: 10
# Scores: (min: 10, avg: 18.333333333333332, max: 47)
#
# Run: 13, exploration: 0.3706551064126331, score: 9
# Scores: (min: 9, avg: 17.615384615384617, max: 47)
#
# Run: 14, exploration: 0.35253382661792404, score: 11
# Scores: (min: 9, avg: 17.142857142857142, max: 47)
#
# Run: 15, exploration: 0.31890579420988907, score: 21
# Scores: (min: 9, avg: 17.4, max: 47)
#
# Run: 16, exploration: 0.3063705780533402, score: 9
# Scores: (min: 9, avg: 16.875, max: 47)
#
# Run: 17, exploration: 0.2730095965279488, score: 24
# Scores: (min: 9, avg: 17.294117647058822, max: 47)
#
# Run: 18, exploration: 0.2532352299289372, score: 16
# Scores: (min: 9, avg: 17.22222222222222, max: 47)
#
# Run: 19, exploration: 0.24206491716205145, score: 10
# Scores: (min: 9, avg: 16.842105263157894, max: 47)
#
# Run: 20, exploration: 0.2290792429684691, score: 12
# Scores: (min: 9, avg: 16.6, max: 47)
#
# Run: 21, exploration: 0.2031139149609751, score: 25
# Scores: (min: 9, avg: 17, max: 47)
#
# Run: 22, exploration: 0.1903004112552766, score: 14
# Scores: (min: 9, avg: 16.863636363636363, max: 47)
#
# Run: 23, exploration: 0.18190617987607657, score: 10
# Scores: (min: 9, avg: 16.565217391304348, max: 47)
#
# Run: 24, exploration: 0.17475600159032884, score: 9
# Scores: (min: 9, avg: 16.25, max: 47)
#
# Run: 25, exploration: 0.1678868750508869, score: 9
# Scores: (min: 9, avg: 15.96, max: 47)
#
# Run: 26, exploration: 0.15888051309497406, score: 12
# Scores: (min: 9, avg: 15.807692307692308, max: 47)
#
# Run: 27, exploration: 0.1518722266715875, score: 10
# Scores: (min: 9, avg: 15.592592592592593, max: 47)
#
# Run: 28, exploration: 0.14444721332374086, score: 11
# Scores: (min: 9, avg: 15.428571428571429, max: 47)
#
# Run: 29, exploration: 0.13669828187021155, score: 12
# Scores: (min: 9, avg: 15.310344827586206, max: 47)
#
# Run: 30, exploration: 0.13066846301911936, score: 10
# Scores: (min: 9, avg: 15.133333333333333, max: 47)
#
# Run: 31, exploration: 0.1255322834371622, score: 9
# Scores: (min: 9, avg: 14.935483870967742, max: 47)
#
# Run: 32, exploration: 0.11999500148501063, score: 10
# Scores: (min: 9, avg: 14.78125, max: 47)
#
# Run: 33, exploration: 0.11470197137452155, score: 10
# Scores: (min: 9, avg: 14.636363636363637, max: 47)
#
# Run: 34, exploration: 0.10909420695870241, score: 11
# Scores: (min: 9, avg: 14.529411764705882, max: 47)
#
# Run: 35, exploration: 0.1042820154910064, score: 10
# Scores: (min: 9, avg: 14.4, max: 47)
#
# Run: 36, exploration: 0.10018300685223579, score: 9
# Scores: (min: 9, avg: 14.25, max: 47)
#
# Run: 37, exploration: 0.09576389217857617, score: 10
# Scores: (min: 9, avg: 14.135135135135135, max: 47)
#
# Run: 38, exploration: 0.09153970651645797, score: 10
# Scores: (min: 9, avg: 14.026315789473685, max: 47)
#
# Run: 39, exploration: 0.08794155926129824, score: 9
# Scores: (min: 9, avg: 13.897435897435898, max: 47)
#
# Run: 40, exploration: 0.08448484422350626, score: 9
# Scores: (min: 9, avg: 13.775, max: 47)
#
# Run: 41, exploration: 0.08035439121179945, score: 11
# Scores: (min: 9, avg: 13.707317073170731, max: 47)
#
# Run: 42, exploration: 0.07642587550895225, score: 11
# Scores: (min: 9, avg: 13.642857142857142, max: 47)
#
# Run: 43, exploration: 0.07342180695061275, score: 9
# Scores: (min: 9, avg: 13.534883720930232, max: 47)
#
# Run: 44, exploration: 0.07053581918419231, score: 9
# Scores: (min: 9, avg: 13.431818181818182, max: 47)
#
# Run: 45, exploration: 0.0677632708131484, score: 9
# Scores: (min: 9, avg: 13.333333333333334, max: 47)
#
# Run: 46, exploration: 0.06412808167716157, score: 12
# Scores: (min: 9, avg: 13.304347826086957, max: 47)
#
# Run: 47, exploration: 0.05918580250061433, score: 17
# Scores: (min: 9, avg: 13.382978723404255, max: 47)
#
# Run: 48, exploration: 0.05685938874076987, score: 9
# Scores: (min: 9, avg: 13.291666666666666, max: 47)
#
# Run: 49, exploration: 0.05489891379418004, score: 8
# Scores: (min: 8, avg: 13.183673469387756, max: 47)
#
# Run: 50, exploration: 0.05195383849590569, score: 12
# Scores: (min: 8, avg: 13.16, max: 47)
#
# Run: 51, exploration: 0.04966213277390804, score: 10
# Scores: (min: 8, avg: 13.098039215686274, max: 47)
#
# Run: 52, exploration: 0.04794981455780219, score: 8
# Scores: (min: 8, avg: 13, max: 47)
#
# Run: 53, exploration: 0.045605554379880814, score: 11
# Scores: (min: 8, avg: 12.962264150943396, max: 47)
#
# Run: 54, exploration: 0.04359387414694703, score: 10
# Scores: (min: 8, avg: 12.907407407407407, max: 47)
#
# Run: 55, exploration: 0.0418803316354751, score: 9
# Scores: (min: 8, avg: 12.836363636363636, max: 47)
#
# Run: 56, exploration: 0.03983280768576652, score: 11
# Scores: (min: 8, avg: 12.803571428571429, max: 47)
#
# Run: 57, exploration: 0.03826710124979409, score: 9
# Scores: (min: 8, avg: 12.736842105263158, max: 47)
#
# Run: 58, exploration: 0.036762937968474095, score: 9
# Scores: (min: 8, avg: 12.672413793103448, max: 47)
#
# Run: 59, exploration: 0.03514130927386981, score: 10
# Scores: (min: 8, avg: 12.627118644067796, max: 47)
#
# Run: 60, exploration: 0.03359121130473201, score: 10
# Scores: (min: 8, avg: 12.583333333333334, max: 47)
#
# Run: 61, exploration: 0.03227084302572862, score: 9
# Scores: (min: 8, avg: 12.524590163934427, max: 47)
#
# Run: 62, exploration: 0.03100237440513238, score: 9
# Scores: (min: 8, avg: 12.46774193548387, max: 47)
#
# Run: 63, exploration: 0.029783765425331846, score: 9
# Scores: (min: 8, avg: 12.412698412698413, max: 47)
#
# Run: 64, exploration: 0.02861305625559891, score: 9
# Scores: (min: 8, avg: 12.359375, max: 47)
#
# Run: 65, exploration: 0.027214167668287145, score: 11
# Scores: (min: 8, avg: 12.338461538461539, max: 47)
#
# Run: 66, exploration: 0.026144461565619025, score: 9
# Scores: (min: 8, avg: 12.287878787878787, max: 47)
#
# Run: 67, exploration: 0.02524301744132218, score: 8
# Scores: (min: 8, avg: 12.223880597014926, max: 47)
#
# Run: 68, exploration: 0.02437265452736848, score: 8
# Scores: (min: 8, avg: 12.161764705882353, max: 47)
#
# Run: 69, exploration: 0.023297566459620722, score: 10
# Scores: (min: 8, avg: 12.130434782608695, max: 47)
#
# Run: 70, exploration: 0.022269900979844076, score: 10
# Scores: (min: 8, avg: 12.1, max: 47)
#
# Run: 71, exploration: 0.02128756625768776, score: 10
# Scores: (min: 8, avg: 12.070422535211268, max: 47)
#
# Run: 72, exploration: 0.020348562734319765, score: 10
# Scores: (min: 8, avg: 12.041666666666666, max: 47)
#
# Run: 73, exploration: 0.019450979052291272, score: 10
# Scores: (min: 8, avg: 12.013698630136986, max: 47)
#
# Run: 74, exploration: 0.018686420266267767, score: 9
# Scores: (min: 8, avg: 11.972972972972974, max: 47)
#
# Run: 75, exploration: 0.017772843617388175, score: 11
# Scores: (min: 8, avg: 11.96, max: 47)
#
# Run: 76, exploration: 0.01707424722777892, score: 9
# Scores: (min: 8, avg: 11.921052631578947, max: 47)
#
# Run: 77, exploration: 0.01632109498333433, score: 10
# Scores: (min: 8, avg: 11.896103896103897, max: 47)
#
# Run: 78, exploration: 0.015138941243677408, score: 16
# Scores: (min: 8, avg: 11.948717948717949, max: 47)
#
# Run: 79, exploration: 0.014543875539898159, score: 9
# Scores: (min: 8, avg: 11.91139240506329, max: 47)
#
# Run: 80, exploration: 0.013832827362230486, score: 11
# Scores: (min: 8, avg: 11.9, max: 47)
#
# Run: 81, exploration: 0.013289101019874787, score: 9
# Scores: (min: 8, avg: 11.864197530864198, max: 47)
#
# Run: 82, exploration: 0.012766746905164949, score: 9
# Scores: (min: 8, avg: 11.829268292682928, max: 47)
# Run: 83, exploration: 0.012203600316175803, score: 10
# Scores: (min: 8, avg: 11.80722891566265, max: 47)
#
# Run: 84, exploration: 0.011723913930325095, score: 9
# Scores: (min: 8, avg: 11.773809523809524, max: 47)
#
# Run: 85, exploration: 0.011263082556340478, score: 9
# Scores: (min: 8, avg: 11.741176470588234, max: 47)
#
# Run: 86, exploration: 0.010820365061092144, score: 9
# Scores: (min: 8, avg: 11.709302325581396, max: 47)
#
# Run: 87, exploration: 0.01, score: 43
# Scores: (min: 8, avg: 12.068965517241379, max: 47)
#
# Run: 88, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.045454545454545, max: 47)
#
# Run: 89, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.03370786516854, max: 47)
#
# Run: 90, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.011111111111111, max: 47)
#
# Run: 91, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.978021978021978, max: 47)
#
# Run: 92, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 12.152173913043478, max: 47)
#
# Run: 93, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.13978494623656, max: 47)
#
# Run: 94, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.117021276595745, max: 47)
#
# Run: 95, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.105263157894736, max: 47)
#
# Run: 96, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.072916666666666, max: 47)
#
# Run: 97, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.061855670103093, max: 47)
#
# Run: 98, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 12.020408163265307, max: 47)
#
# Run: 99, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 12.05050505050505, max: 47)
#
# Run: 100, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 12.1, max: 47)
#
# Run: 101, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 12.08, max: 47)
#
# Run: 102, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.03, max: 47)
#
# Run: 103, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.65, max: 43)
#
# Run: 104, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.57, max: 43)
#
# Run: 105, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.38, max: 43)
#
# Run: 106, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.26, max: 43)
#
# Run: 107, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.24, max: 43)
#
# Run: 108, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 11.18, max: 43)
#
# Run: 109, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.13, max: 43)
#
# Run: 110, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.1, max: 43)
#
# Run: 111, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 11.13, max: 43)
#
# Run: 112, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.14, max: 43)
#
# Run: 113, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.16, max: 43)
#
# Run: 114, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 11.18, max: 43)
#
# Run: 115, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 11.1, max: 43)
#
# Run: 116, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 11.14, max: 43)
#
# Run: 117, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 11.07, max: 43)
#
# Run: 118, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 11.06, max: 43)
#
# Run: 119, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.05, max: 43)
#
# Run: 120, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 11.05, max: 43)
#
# Run: 121, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 10.98, max: 43)
#
# Run: 122, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 11.07, max: 43)
#
# Run: 123, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 11.1, max: 43)
#
# Run: 124, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 11.14, max: 43)
#
# Run: 125, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 11.25, max: 43)
#
# Run: 126, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.23, max: 43)
#
# Run: 127, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 11.28, max: 43)
#
# Run: 128, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 11.36, max: 43)
#
# Run: 129, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 11.45, max: 43)
#
# Run: 130, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 11.57, max: 43)
#
# Run: 131, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.59, max: 43)
#
# Run: 132, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 11.65, max: 43)
#
# Run: 133, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 11.7, max: 43)
#
# Run: 134, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 11.74, max: 43)
#
# Run: 135, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 11.85, max: 43)
#
# Run: 136, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 11.92, max: 43)
#
# Run: 137, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 11.96, max: 43)
#
# Run: 138, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 12.03, max: 43)
#
# Run: 139, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 12.07, max: 43)
#
# Run: 140, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 12.12, max: 43)
#
# Run: 141, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 12.16, max: 43)
#
# Run: 142, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 12.28, max: 43)
#
# Run: 143, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 12.39, max: 43)
#
# Run: 144, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 12.5, max: 43)
#
# Run: 145, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 12.62, max: 43)
#
# Run: 146, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 12.63, max: 43)
#
# Run: 147, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 12.67, max: 43)
#
# Run: 148, exploration: 0.01, score: 41
# Scores: (min: 8, avg: 12.99, max: 43)
#
# Run: 149, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 13.14, max: 43)
#
# Run: 150, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 13.2, max: 43)
#
# Run: 151, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 13.32, max: 43)
#
# Run: 152, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 13.38, max: 43)
#
# Run: 153, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 13.51, max: 43)
#
# Run: 154, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 13.6, max: 43)
#
# Run: 155, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 13.75, max: 43)
#
# Run: 156, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 13.88, max: 43)
#
# Run: 157, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 14.06, max: 43)
#
# Run: 158, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 14.17, max: 43)
#
# Run: 159, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 14.31, max: 43)
#
# Run: 160, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 14.5, max: 43)
#
# Run: 161, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 14.57, max: 43)
#
# Run: 162, exploration: 0.01, score: 49
# Scores: (min: 8, avg: 14.97, max: 49)
#
# Run: 163, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 15.08, max: 49)
#
# Run: 164, exploration: 0.01, score: 42
# Scores: (min: 8, avg: 15.41, max: 49)
#
# Run: 165, exploration: 0.01, score: 43
# Scores: (min: 8, avg: 15.73, max: 49)
#
# Run: 166, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 15.79, max: 49)
#
# Run: 167, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 16.08, max: 49)
#
# Run: 168, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 16.34, max: 49)
#
# Run: 169, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 16.48, max: 49)
#
# Run: 170, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 16.57, max: 49)
#
# Run: 171, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 16.75, max: 49)
#
# Run: 172, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 16.77, max: 49)
#
# Run: 173, exploration: 0.01, score: 35
# Scores: (min: 8, avg: 17.02, max: 49)
#
# Run: 174, exploration: 0.01, score: 47
# Scores: (min: 8, avg: 17.4, max: 49)
#
# Run: 175, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 17.6, max: 49)
#
# Run: 176, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 17.65, max: 49)
#
# Run: 177, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 17.81, max: 49)
#
# Run: 178, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 17.97, max: 49)
#
# Run: 179, exploration: 0.01, score: 38
# Scores: (min: 8, avg: 18.26, max: 49)
#
# Run: 180, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 18.4, max: 49)
#
# Run: 181, exploration: 0.01, score: 40
# Scores: (min: 8, avg: 18.71, max: 49)
#
# Run: 182, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 18.81, max: 49)
#
# Run: 183, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 18.97, max: 49)
#
# Run: 184, exploration: 0.01, score: 79
# Scores: (min: 8, avg: 19.67, max: 79)
# Run: 185, exploration: 0.01, score: 57
# Scores: (min: 8, avg: 20.15, max: 79)
#
# Run: 186, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 20.31, max: 79)
#
# Run: 187, exploration: 0.01, score: 47
# Scores: (min: 8, avg: 20.35, max: 79)
#
# Run: 188, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 20.53, max: 79)
#
# Run: 189, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 20.64, max: 79)
#
# Run: 190, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 20.9, max: 79)
#
# Run: 191, exploration: 0.01, score: 59
# Scores: (min: 8, avg: 21.4, max: 79)
#
# Run: 192, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 21.25, max: 79)
#
# Run: 193, exploration: 0.01, score: 109
# Scores: (min: 8, avg: 22.23, max: 109)
#
# Run: 194, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 22.41, max: 109)
#
# Run: 195, exploration: 0.01, score: 79
# Scores: (min: 8, avg: 23.09, max: 109)
#
# Run: 196, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 23.34, max: 109)
#
# Run: 197, exploration: 0.01, score: 58
# Scores: (min: 8, avg: 23.81, max: 109)
#
# Run: 198, exploration: 0.01, score: 149
# Scores: (min: 8, avg: 25.22, max: 149)
#
# Run: 199, exploration: 0.01, score: 59
# Scores: (min: 8, avg: 25.66, max: 149)
#
# Run: 200, exploration: 0.01, score: 128
# Scores: (min: 8, avg: 26.77, max: 149)
#
# Run: 201, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 26.94, max: 149)
#
# Run: 202, exploration: 0.01, score: 107
# Scores: (min: 8, avg: 27.9, max: 149)
#
# Run: 203, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 28.1, max: 149)
#
# Run: 204, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 28.19, max: 149)
#
# Run: 205, exploration: 0.01, score: 105
# Scores: (min: 8, avg: 29.14, max: 149)
#
# Run: 206, exploration: 0.01, score: 76
# Scores: (min: 8, avg: 29.81, max: 149)
#
# Run: 207, exploration: 0.01, score: 39
# Scores: (min: 8, avg: 30.1, max: 149)
#
# Run: 208, exploration: 0.01, score: 27
# Scores: (min: 9, avg: 30.29, max: 149)
#
# Run: 209, exploration: 0.01, score: 76
# Scores: (min: 9, avg: 30.96, max: 149)
#
# Run: 210, exploration: 0.01, score: 55
# Scores: (min: 9, avg: 31.42, max: 149)
#
# Run: 211, exploration: 0.01, score: 98
# Scores: (min: 9, avg: 32.27, max: 149)
#
# Run: 212, exploration: 0.01, score: 27
# Scores: (min: 9, avg: 32.43, max: 149)
#
# Run: 213, exploration: 0.01, score: 31
# Scores: (min: 9, avg: 32.63, max: 149)
#
# Run: 214, exploration: 0.01, score: 130
# Scores: (min: 9, avg: 33.8, max: 149)
#
# Run: 215, exploration: 0.01, score: 40
# Scores: (min: 9, avg: 34.07, max: 149)
#
# Run: 216, exploration: 0.01, score: 31
# Scores: (min: 9, avg: 34.25, max: 149)
#
# Run: 217, exploration: 0.01, score: 32
# Scores: (min: 9, avg: 34.4, max: 149)
#
# Run: 218, exploration: 0.01, score: 25
# Scores: (min: 9, avg: 34.5, max: 149)
#
# Run: 219, exploration: 0.01, score: 14
# Scores: (min: 10, avg: 34.55, max: 149)
#
# Run: 220, exploration: 0.01, score: 15
# Scores: (min: 10, avg: 34.58, max: 149)
#
# Run: 221, exploration: 0.01, score: 171
# Scores: (min: 10, avg: 36.11, max: 171)
#
# Run: 222, exploration: 0.01, score: 87
# Scores: (min: 10, avg: 36.75, max: 171)
#
# Run: 223, exploration: 0.01, score: 69
# Scores: (min: 10, avg: 37.31, max: 171)
#
# Run: 224, exploration: 0.01, score: 57
# Scores: (min: 10, avg: 37.75, max: 171)
#
# Run: 225, exploration: 0.01, score: 23
# Scores: (min: 10, avg: 37.78, max: 171)
#
# Run: 226, exploration: 0.01, score: 76
# Scores: (min: 11, avg: 38.44, max: 171)
#
# Run: 227, exploration: 0.01, score: 63
# Scores: (min: 11, avg: 38.92, max: 171)
#
# Run: 228, exploration: 0.01, score: 42
# Scores: (min: 11, avg: 39.15, max: 171)
#
# Run: 229, exploration: 0.01, score: 27
# Scores: (min: 11, avg: 39.21, max: 171)
#
# Run: 230, exploration: 0.01, score: 19
# Scores: (min: 11, avg: 39.18, max: 171)
#
# Run: 231, exploration: 0.01, score: 62
# Scores: (min: 12, avg: 39.69, max: 171)
#
# Run: 232, exploration: 0.01, score: 91
# Scores: (min: 12, avg: 40.44, max: 171)
#
# Run: 233, exploration: 0.01, score: 42
# Scores: (min: 12, avg: 40.71, max: 171)
#
# Run: 234, exploration: 0.01, score: 45
# Scores: (min: 12, avg: 41.01, max: 171)
#
# Run: 235, exploration: 0.01, score: 84
# Scores: (min: 12, avg: 41.64, max: 171)
#
# Run: 236, exploration: 0.01, score: 30
# Scores: (min: 12, avg: 41.78, max: 171)
#
# Run: 237, exploration: 0.01, score: 73
# Scores: (min: 12, avg: 42.37, max: 171)
#
# Run: 238, exploration: 0.01, score: 81
# Scores: (min: 12, avg: 43.01, max: 171)
#
# Run: 239, exploration: 0.01, score: 86
# Scores: (min: 12, avg: 43.74, max: 171)
#
# Run: 240, exploration: 0.01, score: 55
# Scores: (min: 12, avg: 44.15, max: 171)
#
# Run: 241, exploration: 0.01, score: 59
# Scores: (min: 12, avg: 44.59, max: 171)
#
# Run: 242, exploration: 0.01, score: 113
# Scores: (min: 12, avg: 45.49, max: 171)
#
# Run: 243, exploration: 0.01, score: 81
# Scores: (min: 12, avg: 46.1, max: 171)
#
# Run: 244, exploration: 0.01, score: 13
# Scores: (min: 12, avg: 46.03, max: 171)
#
# Run: 245, exploration: 0.01, score: 55
# Scores: (min: 12, avg: 46.37, max: 171)
#
# Run: 246, exploration: 0.01, score: 59
# Scores: (min: 12, avg: 46.83, max: 171)
#
# Run: 247, exploration: 0.01, score: 45
# Scores: (min: 12, avg: 47.07, max: 171)
#
# Run: 248, exploration: 0.01, score: 95
# Scores: (min: 12, avg: 47.61, max: 171)
#
# Run: 249, exploration: 0.01, score: 29
# Scores: (min: 12, avg: 47.67, max: 171)
#
# Run: 250, exploration: 0.01, score: 68
# Scores: (min: 12, avg: 48.17, max: 171)
#
# Run: 251, exploration: 0.01, score: 13
# Scores: (min: 12, avg: 48.08, max: 171)
#
# Run: 252, exploration: 0.01, score: 99
# Scores: (min: 12, avg: 48.93, max: 171)
#
# Run: 253, exploration: 0.01, score: 79
# Scores: (min: 12, avg: 49.48, max: 171)
#
# Run: 254, exploration: 0.01, score: 57
# Scores: (min: 12, avg: 49.86, max: 171)
#
# Run: 255, exploration: 0.01, score: 98
# Scores: (min: 12, avg: 50.6, max: 171)
#
# Run: 256, exploration: 0.01, score: 98
# Scores: (min: 12, avg: 51.34, max: 171)
#
# Run: 257, exploration: 0.01, score: 34
# Scores: (min: 12, avg: 51.41, max: 171)
#
# Run: 258, exploration: 0.01, score: 33
# Scores: (min: 12, avg: 51.54, max: 171)
#
# Run: 259, exploration: 0.01, score: 24
# Scores: (min: 12, avg: 51.54, max: 171)
#
# Run: 260, exploration: 0.01, score: 63
# Scores: (min: 12, avg: 51.88, max: 171)
#
# Run: 261, exploration: 0.01, score: 32
# Scores: (min: 12, avg: 52.04, max: 171)
#
# Run: 262, exploration: 0.01, score: 58
# Scores: (min: 12, avg: 52.13, max: 171)
#
# Run: 263, exploration: 0.01, score: 20
# Scores: (min: 12, avg: 52.13, max: 171)
#
# Run: 264, exploration: 0.01, score: 24
# Scores: (min: 12, avg: 51.95, max: 171)
#
# Run: 265, exploration: 0.01, score: 213
# Scores: (min: 12, avg: 53.65, max: 213)
#
# Run: 266, exploration: 0.01, score: 106
# Scores: (min: 12, avg: 54.56, max: 213)
#
# Run: 267, exploration: 0.01, score: 68
# Scores: (min: 12, avg: 54.87, max: 213)
#
# Run: 268, exploration: 0.01, score: 53
# Scores: (min: 12, avg: 55.06, max: 213)
#
# Run: 269, exploration: 0.01, score: 34
# Scores: (min: 12, avg: 55.16, max: 213)
#
# Run: 270, exploration: 0.01, score: 54
# Scores: (min: 12, avg: 55.51, max: 213)
#
# Run: 271, exploration: 0.01, score: 114
# Scores: (min: 12, avg: 56.37, max: 213)
#
# Run: 272, exploration: 0.01, score: 14
# Scores: (min: 13, avg: 56.39, max: 213)
#
# Run: 273, exploration: 0.01, score: 51
# Scores: (min: 13, avg: 56.55, max: 213)
#
# Run: 274, exploration: 0.01, score: 39
# Scores: (min: 13, avg: 56.47, max: 213)
#
# Run: 275, exploration: 0.01, score: 109
# Scores: (min: 13, avg: 57.25, max: 213)
#
# Run: 276, exploration: 0.01, score: 45
# Scores: (min: 13, avg: 57.56, max: 213)
#
# Run: 277, exploration: 0.01, score: 163
# Scores: (min: 13, avg: 58.93, max: 213)
#
# Run: 278, exploration: 0.01, score: 32
# Scores: (min: 13, avg: 58.93, max: 213)
#
# Run: 279, exploration: 0.01, score: 21
# Scores: (min: 13, avg: 58.76, max: 213)
#
# Run: 280, exploration: 0.01, score: 122
# Scores: (min: 13, avg: 59.73, max: 213)
#
# Run: 281, exploration: 0.01, score: 58
# Scores: (min: 13, avg: 59.91, max: 213)
#
# Run: 282, exploration: 0.01, score: 25
# Scores: (min: 13, avg: 59.97, max: 213)
#
# Run: 283, exploration: 0.01, score: 39
# Scores: (min: 13, avg: 60.1, max: 213)
#
# Run: 284, exploration: 0.01, score: 86
# Scores: (min: 13, avg: 60.17, max: 213)
#
# Run: 285, exploration: 0.01, score: 30
# Scores: (min: 13, avg: 59.9, max: 213)
#
# Run: 286, exploration: 0.01, score: 19
# Scores: (min: 13, avg: 59.84, max: 213)
#
# Run: 287, exploration: 0.01, score: 78
# Scores: (min: 13, avg: 60.15, max: 213)
# Run: 288, exploration: 0.01, score: 95
# Scores: (min: 13, avg: 60.82, max: 213)
#
# Run: 289, exploration: 0.01, score: 45
# Scores: (min: 13, avg: 61.05, max: 213)
#
# Run: 290, exploration: 0.01, score: 23
# Scores: (min: 13, avg: 60.92, max: 213)
#
# Run: 291, exploration: 0.01, score: 56
# Scores: (min: 13, avg: 60.89, max: 213)
#
# Run: 292, exploration: 0.01, score: 32
# Scores: (min: 13, avg: 61.08, max: 213)
#
# Run: 293, exploration: 0.01, score: 32
# Scores: (min: 13, avg: 60.31, max: 213)
#
# Run: 294, exploration: 0.01, score: 86
# Scores: (min: 13, avg: 60.89, max: 213)
#
# Run: 295, exploration: 0.01, score: 96
# Scores: (min: 13, avg: 61.06, max: 213)
#
# Run: 296, exploration: 0.01, score: 32
# Scores: (min: 13, avg: 61.04, max: 213)
#
# Run: 297, exploration: 0.01, score: 61
# Scores: (min: 13, avg: 61.07, max: 213)
#
# Run: 298, exploration: 0.01, score: 18
# Scores: (min: 13, avg: 59.76, max: 213)
#
# Run: 299, exploration: 0.01, score: 15
# Scores: (min: 13, avg: 59.32, max: 213)
#
# Run: 300, exploration: 0.01, score: 52
# Scores: (min: 13, avg: 58.56, max: 213)
#
# Run: 301, exploration: 0.01, score: 110
# Scores: (min: 13, avg: 59.34, max: 213)
#
# Run: 302, exploration: 0.01, score: 87
# Scores: (min: 13, avg: 59.14, max: 213)
#
# Run: 303, exploration: 0.01, score: 79
# Scores: (min: 13, avg: 59.64, max: 213)
#
# Run: 304, exploration: 0.01, score: 24
# Scores: (min: 13, avg: 59.69, max: 213)
#
# Run: 305, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 58.73, max: 213)
#
# Run: 306, exploration: 0.01, score: 30
# Scores: (min: 9, avg: 58.27, max: 213)
#
# Run: 307, exploration: 0.01, score: 59
# Scores: (min: 9, avg: 58.47, max: 213)
#
# Run: 308, exploration: 0.01, score: 55
# Scores: (min: 9, avg: 58.75, max: 213)
#
# Run: 309, exploration: 0.01, score: 44
# Scores: (min: 9, avg: 58.43, max: 213)
#
# Run: 310, exploration: 0.01, score: 26
# Scores: (min: 9, avg: 58.14, max: 213)
#
# Run: 311, exploration: 0.01, score: 108
# Scores: (min: 9, avg: 58.24, max: 213)
#
# Run: 312, exploration: 0.01, score: 152
# Scores: (min: 9, avg: 59.49, max: 213)
#
# Run: 313, exploration: 0.01, score: 80
# Scores: (min: 9, avg: 59.98, max: 213)
#
# Run: 314, exploration: 0.01, score: 96
# Scores: (min: 9, avg: 59.64, max: 213)
#
# Run: 315, exploration: 0.01, score: 113
# Scores: (min: 9, avg: 60.37, max: 213)
#
# Run: 316, exploration: 0.01, score: 99
# Scores: (min: 9, avg: 61.05, max: 213)
#
# Run: 317, exploration: 0.01, score: 14
# Scores: (min: 9, avg: 60.87, max: 213)
#
# Run: 318, exploration: 0.01, score: 63
# Scores: (min: 9, avg: 61.25, max: 213)
#
# Run: 319, exploration: 0.01, score: 78
# Scores: (min: 9, avg: 61.89, max: 213)
#
# Run: 320, exploration: 0.01, score: 12
# Scores: (min: 9, avg: 61.86, max: 213)
#
# Run: 321, exploration: 0.01, score: 84
# Scores: (min: 9, avg: 60.99, max: 213)
#
# Run: 322, exploration: 0.01, score: 13
# Scores: (min: 9, avg: 60.25, max: 213)
#
# Run: 323, exploration: 0.01, score: 77
# Scores: (min: 9, avg: 60.33, max: 213)
#
# Run: 324, exploration: 0.01, score: 51
# Scores: (min: 9, avg: 60.27, max: 213)
#
# Run: 325, exploration: 0.01, score: 113
# Scores: (min: 9, avg: 61.17, max: 213)
#
# Run: 326, exploration: 0.01, score: 29
# Scores: (min: 9, avg: 60.7, max: 213)
#
# Run: 327, exploration: 0.01, score: 65
# Scores: (min: 9, avg: 60.72, max: 213)
#
# Run: 328, exploration: 0.01, score: 181
# Scores: (min: 9, avg: 62.11, max: 213)
#
# Run: 329, exploration: 0.01, score: 34
# Scores: (min: 9, avg: 62.18, max: 213)
#
# Run: 330, exploration: 0.01, score: 31
# Scores: (min: 9, avg: 62.3, max: 213)
#
# Run: 331, exploration: 0.01, score: 114
# Scores: (min: 9, avg: 62.82, max: 213)
#
# Run: 332, exploration: 0.01, score: 96
# Scores: (min: 9, avg: 62.87, max: 213)
#
# Run: 333, exploration: 0.01, score: 147
# Scores: (min: 9, avg: 63.92, max: 213)
#
# Run: 334, exploration: 0.01, score: 52
# Scores: (min: 9, avg: 63.99, max: 213)
#
# Run: 335, exploration: 0.01, score: 105
# Scores: (min: 9, avg: 64.2, max: 213)
#
# Run: 336, exploration: 0.01, score: 202
# Scores: (min: 9, avg: 65.92, max: 213)
#
# Run: 337, exploration: 0.01, score: 148
# Scores: (min: 9, avg: 66.67, max: 213)
#
# Run: 338, exploration: 0.01, score: 105
# Scores: (min: 9, avg: 66.91, max: 213)
#
# Run: 339, exploration: 0.01, score: 140
# Scores: (min: 9, avg: 67.45, max: 213)
#
# Run: 340, exploration: 0.01, score: 61
# Scores: (min: 9, avg: 67.51, max: 213)
#
# Run: 341, exploration: 0.01, score: 55
# Scores: (min: 9, avg: 67.47, max: 213)
#
# Run: 342, exploration: 0.01, score: 98
# Scores: (min: 9, avg: 67.32, max: 213)
#
# Run: 343, exploration: 0.01, score: 104
# Scores: (min: 9, avg: 67.55, max: 213)
#
# Run: 344, exploration: 0.01, score: 105
# Scores: (min: 9, avg: 68.47, max: 213)
#
# Run: 345, exploration: 0.01, score: 106
# Scores: (min: 9, avg: 68.98, max: 213)
#
# Run: 346, exploration: 0.01, score: 156
# Scores: (min: 9, avg: 69.95, max: 213)
#
# Run: 347, exploration: 0.01, score: 135
# Scores: (min: 9, avg: 70.85, max: 213)
#
# Run: 348, exploration: 0.01, score: 67
# Scores: (min: 9, avg: 70.57, max: 213)
#
# Run: 349, exploration: 0.01, score: 37
# Scores: (min: 9, avg: 70.65, max: 213)
#
# Run: 350, exploration: 0.01, score: 113
# Scores: (min: 9, avg: 71.1, max: 213)
#
# Run: 351, exploration: 0.01, score: 133
# Scores: (min: 9, avg: 72.3, max: 213)
#
# Run: 352, exploration: 0.01, score: 193
# Scores: (min: 9, avg: 73.24, max: 213)
#
# Run: 353, exploration: 0.01, score: 13
# Scores: (min: 9, avg: 72.58, max: 213)
#
# Run: 354, exploration: 0.01, score: 229
# Scores: (min: 9, avg: 74.3, max: 229)
#
# Run: 355, exploration: 0.01, score: 145
# Scores: (min: 9, avg: 74.77, max: 229)
#
# Run: 356, exploration: 0.01, score: 172
# Scores: (min: 9, avg: 75.51, max: 229)
#
# Run: 357, exploration: 0.01, score: 94
# Scores: (min: 9, avg: 76.11, max: 229)
#
# Run: 358, exploration: 0.01, score: 244
# Scores: (min: 9, avg: 78.22, max: 244)
#
# Run: 359, exploration: 0.01, score: 30
# Scores: (min: 9, avg: 78.28, max: 244)
#
# Run: 360, exploration: 0.01, score: 198
# Scores: (min: 9, avg: 79.63, max: 244)
#
# Run: 361, exploration: 0.01, score: 152
# Scores: (min: 9, avg: 80.83, max: 244)
#
# Run: 362, exploration: 0.01, score: 127
# Scores: (min: 9, avg: 81.52, max: 244)
#
# Run: 363, exploration: 0.01, score: 21
# Scores: (min: 9, avg: 81.53, max: 244)
#
# Run: 364, exploration: 0.01, score: 100
# Scores: (min: 9, avg: 82.29, max: 244)
#
# Run: 365, exploration: 0.01, score: 67
# Scores: (min: 9, avg: 80.83, max: 244)
#
# Run: 366, exploration: 0.01, score: 121
# Scores: (min: 9, avg: 80.98, max: 244)
#
# Run: 367, exploration: 0.01, score: 189
# Scores: (min: 9, avg: 82.19, max: 244)
#
# Run: 368, exploration: 0.01, score: 167
# Scores: (min: 9, avg: 83.33, max: 244)
#
# Run: 369, exploration: 0.01, score: 120
# Scores: (min: 9, avg: 84.19, max: 244)
#
# Run: 370, exploration: 0.01, score: 174
# Scores: (min: 9, avg: 85.39, max: 244)
#
# Run: 371, exploration: 0.01, score: 138
# Scores: (min: 9, avg: 85.63, max: 244)
#
# Run: 372, exploration: 0.01, score: 126
# Scores: (min: 9, avg: 86.75, max: 244)
#
# Run: 373, exploration: 0.01, score: 327
# Scores: (min: 9, avg: 89.51, max: 327)
#
# Run: 374, exploration: 0.01, score: 108
# Scores: (min: 9, avg: 90.2, max: 327)
#
# Run: 375, exploration: 0.01, score: 29
# Scores: (min: 9, avg: 89.4, max: 327)
#
# Run: 376, exploration: 0.01, score: 111
# Scores: (min: 9, avg: 90.06, max: 327)
#
# Run: 377, exploration: 0.01, score: 90
# Scores: (min: 9, avg: 89.33, max: 327)
#
# Run: 378, exploration: 0.01, score: 77
# Scores: (min: 9, avg: 89.78, max: 327)
#
# Run: 379, exploration: 0.01, score: 52
# Scores: (min: 9, avg: 90.09, max: 327)
#
# Run: 380, exploration: 0.01, score: 61
# Scores: (min: 9, avg: 89.48, max: 327)
#
# Run: 381, exploration: 0.01, score: 82
# Scores: (min: 9, avg: 89.72, max: 327)
#
# Run: 382, exploration: 0.01, score: 101
# Scores: (min: 9, avg: 90.48, max: 327)
#
# Run: 383, exploration: 0.01, score: 103
# Scores: (min: 9, avg: 91.12, max: 327)
#
# Run: 384, exploration: 0.01, score: 285
# Scores: (min: 9, avg: 93.11, max: 327)
#
# Run: 385, exploration: 0.01, score: 308
# Scores: (min: 9, avg: 95.89, max: 327)
#
# Run: 386, exploration: 0.01, score: 177
# Scores: (min: 9, avg: 97.47, max: 327)
#
# Run: 387, exploration: 0.01, score: 77
# Scores: (min: 9, avg: 97.46, max: 327)
#
# Run: 388, exploration: 0.01, score: 75
# Scores: (min: 9, avg: 97.26, max: 327)
#
# Run: 389, exploration: 0.01, score: 37
# Scores: (min: 9, avg: 97.18, max: 327)
#
# Run: 390, exploration: 0.01, score: 204
# Scores: (min: 9, avg: 98.99, max: 327)
#
# Run: 391, exploration: 0.01, score: 238
# Scores: (min: 9, avg: 100.81, max: 327)
# Run: 392, exploration: 0.01, score: 446
# Scores: (min: 9, avg: 104.95, max: 446)
#
# Run: 393, exploration: 0.01, score: 217
# Scores: (min: 9, avg: 106.8, max: 446)
#
# Run: 394, exploration: 0.01, score: 322
# Scores: (min: 9, avg: 109.16, max: 446)
#
# Run: 395, exploration: 0.01, score: 117
# Scores: (min: 9, avg: 109.37, max: 446)
#
# Run: 396, exploration: 0.01, score: 267
# Scores: (min: 9, avg: 111.72, max: 446)
#
# Run: 397, exploration: 0.01, score: 209
# Scores: (min: 9, avg: 113.2, max: 446)
#
# Run: 398, exploration: 0.01, score: 162
# Scores: (min: 9, avg: 114.64, max: 446)
#
# Run: 399, exploration: 0.01, score: 192
# Scores: (min: 9, avg: 116.41, max: 446)
#
# Run: 400, exploration: 0.01, score: 239
# Scores: (min: 9, avg: 118.28, max: 446)
#
# Run: 401, exploration: 0.01, score: 125
# Scores: (min: 9, avg: 118.43, max: 446)
#
# Run: 402, exploration: 0.01, score: 137
# Scores: (min: 9, avg: 118.93, max: 446)
#
# Run: 403, exploration: 0.01, score: 373
# Scores: (min: 9, avg: 121.87, max: 446)
#
# Run: 404, exploration: 0.01, score: 25
# Scores: (min: 9, avg: 121.88, max: 446)
#
# Run: 405, exploration: 0.01, score: 184
# Scores: (min: 12, avg: 123.63, max: 446)
#
# Run: 406, exploration: 0.01, score: 500
# Scores: (min: 12, avg: 128.33, max: 500)
#
# Run: 407, exploration: 0.01, score: 194
# Scores: (min: 12, avg: 129.68, max: 500)
#
# Run: 408, exploration: 0.01, score: 195
# Scores: (min: 12, avg: 131.08, max: 500)
#
# Run: 409, exploration: 0.01, score: 222
# Scores: (min: 12, avg: 132.86, max: 500)
#
# Run: 410, exploration: 0.01, score: 181
# Scores: (min: 12, avg: 134.41, max: 500)
#
# Run: 411, exploration: 0.01, score: 188
# Scores: (min: 12, avg: 135.21, max: 500)
#
# Run: 412, exploration: 0.01, score: 194
# Scores: (min: 12, avg: 135.63, max: 500)
#
# Run: 413, exploration: 0.01, score: 311
# Scores: (min: 12, avg: 137.94, max: 500)
#
# Run: 414, exploration: 0.01, score: 298
# Scores: (min: 12, avg: 139.96, max: 500)
#
# Run: 415, exploration: 0.01, score: 291
# Scores: (min: 12, avg: 141.74, max: 500)
#
# Run: 416, exploration: 0.01, score: 393
# Scores: (min: 12, avg: 144.68, max: 500)
#
# Run: 417, exploration: 0.01, score: 249
# Scores: (min: 12, avg: 147.03, max: 500)
#
# Run: 418, exploration: 0.01, score: 177
# Scores: (min: 12, avg: 148.17, max: 500)
#
# Run: 419, exploration: 0.01, score: 168
# Scores: (min: 12, avg: 149.07, max: 500)
#
# Run: 420, exploration: 0.01, score: 235
# Scores: (min: 13, avg: 151.3, max: 500)
#
# Run: 421, exploration: 0.01, score: 310
# Scores: (min: 13, avg: 153.56, max: 500)
#
# Run: 422, exploration: 0.01, score: 178
# Scores: (min: 13, avg: 155.21, max: 500)
#
# Run: 423, exploration: 0.01, score: 33
# Scores: (min: 13, avg: 154.77, max: 500)
#
# Run: 424, exploration: 0.01, score: 221
# Scores: (min: 13, avg: 156.47, max: 500)
#
# Run: 425, exploration: 0.01, score: 140
# Scores: (min: 13, avg: 156.74, max: 500)
#
# Run: 426, exploration: 0.01, score: 210
# Scores: (min: 13, avg: 158.55, max: 500)
#
# Run: 427, exploration: 0.01, score: 246
# Scores: (min: 13, avg: 160.36, max: 500)
#
# Run: 428, exploration: 0.01, score: 188
# Scores: (min: 13, avg: 160.43, max: 500)
#
# Run: 429, exploration: 0.01, score: 240
# Scores: (min: 13, avg: 162.49, max: 500)
#
# Run: 430, exploration: 0.01, score: 240
# Scores: (min: 13, avg: 164.58, max: 500)
#
# Run: 431, exploration: 0.01, score: 222
# Scores: (min: 13, avg: 165.66, max: 500)
#
# Run: 432, exploration: 0.01, score: 191
# Scores: (min: 13, avg: 166.61, max: 500)
#
# Run: 433, exploration: 0.01, score: 250
# Scores: (min: 13, avg: 167.64, max: 500)
#
# Run: 434, exploration: 0.01, score: 245
# Scores: (min: 13, avg: 169.57, max: 500)
#
# Run: 435, exploration: 0.01, score: 142
# Scores: (min: 13, avg: 169.94, max: 500)
#
# Run: 436, exploration: 0.01, score: 365
# Scores: (min: 13, avg: 171.57, max: 500)
#
# Run: 437, exploration: 0.01, score: 318
# Scores: (min: 13, avg: 173.27, max: 500)
#
# Run: 438, exploration: 0.01, score: 184
# Scores: (min: 13, avg: 174.06, max: 500)
#
# Run: 439, exploration: 0.01, score: 146
# Scores: (min: 13, avg: 174.12, max: 500)
#
# Run: 440, exploration: 0.01, score: 221
# Scores: (min: 13, avg: 175.72, max: 500)
#
# Run: 441, exploration: 0.01, score: 152
# Scores: (min: 13, avg: 176.69, max: 500)
#
# Run: 442, exploration: 0.01, score: 156
# Scores: (min: 13, avg: 177.27, max: 500)
#
# Run: 443, exploration: 0.01, score: 229
# Scores: (min: 13, avg: 178.52, max: 500)
#
# Run: 444, exploration: 0.01, score: 289
# Scores: (min: 13, avg: 180.36, max: 500)
#
# Run: 445, exploration: 0.01, score: 351
# Scores: (min: 13, avg: 182.81, max: 500)
#
# Run: 446, exploration: 0.01, score: 76
# Scores: (min: 13, avg: 182.01, max: 500)
#
# Run: 447, exploration: 0.01, score: 185
# Scores: (min: 13, avg: 182.51, max: 500)
#
# Run: 448, exploration: 0.01, score: 250
# Scores: (min: 13, avg: 184.34, max: 500)
#
# Run: 449, exploration: 0.01, score: 275
# Scores: (min: 13, avg: 186.72, max: 500)
#
# Run: 450, exploration: 0.01, score: 400
# Scores: (min: 13, avg: 189.59, max: 500)
#
# Run: 451, exploration: 0.01, score: 368
# Scores: (min: 13, avg: 191.94, max: 500)
#
# Run: 452, exploration: 0.01, score: 324
# Scores: (min: 13, avg: 193.25, max: 500)
#
# Run: 453, exploration: 0.01, score: 251
# Scores: (min: 21, avg: 195.63, max: 500)
#
# Solved in 353 runs, 453 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9888\682879775.py in <module>
# ----> 1 cartpole()
#
# ~\AppData\Local\Temp\ipykernel_9888\1179614723.py in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# ~\1CS-370\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.95  
LEARNING_RATE = 0.001  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 0.5  
EXPLORATION_MIN = 0.1  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()

# %%
cartpole()
# Out:
# Run: 1, exploration: 0.5, score: 10
# Scores: (min: 10, avg: 10, max: 10)
#
# Run: 2, exploration: 0.48518625467813287, score: 16
# Scores: (min: 10, avg: 13, max: 16)
#
# Run: 3, exploration: 0.4345264977726301, score: 23
# Scores: (min: 10, avg: 16.333333333333332, max: 23)
#
# Run: 4, exploration: 0.4174465836593632, score: 9
# Scores: (min: 9, avg: 14.5, max: 23)
#
# Run: 5, exploration: 0.40103802898588187, score: 9
# Scores: (min: 9, avg: 13.4, max: 23)
#
# Run: 6, exploration: 0.37762655453309485, score: 13
# Scores: (min: 9, avg: 13.333333333333334, max: 23)
#
# Run: 7, exploration: 0.3646062351852308, score: 8
# Scores: (min: 8, avg: 12.571428571428571, max: 23)
#
# Run: 8, exploration: 0.3485233004177475, score: 10
# Scores: (min: 8, avg: 12.25, max: 23)
#
# Run: 9, exploration: 0.3331497906841058, score: 10
# Scores: (min: 8, avg: 12, max: 23)
#
# Run: 10, exploration: 0.3200546863788332, score: 9
# Scores: (min: 8, avg: 11.7, max: 23)
#
# Run: 11, exploration: 0.3013707921541371, score: 13
# Scores: (min: 8, avg: 11.818181818181818, max: 23)
#
# Run: 12, exploration: 0.2880771994415019, score: 10
# Scores: (min: 8, avg: 11.666666666666666, max: 23)
#
# Run: 13, exploration: 0.2753699927085638, score: 10
# Scores: (min: 8, avg: 11.538461538461538, max: 23)
#
# Run: 14, exploration: 0.2605976537429438, score: 12
# Scores: (min: 8, avg: 11.571428571428571, max: 23)
#
# Run: 15, exploration: 0.2503543531229265, score: 9
# Scores: (min: 8, avg: 11.4, max: 23)
#
# Run: 16, exploration: 0.22990452539698744, score: 18
# Scores: (min: 8, avg: 11.8125, max: 23)
#
# Run: 17, exploration: 0.21540092780399553, score: 14
# Scores: (min: 8, avg: 11.941176470588236, max: 23)
#
# Run: 18, exploration: 0.20487000454610652, score: 11
# Scores: (min: 8, avg: 11.88888888888889, max: 23)
#
# Run: 19, exploration: 0.19291026873326575, score: 13
# Scores: (min: 8, avg: 11.947368421052632, max: 23)
#
# Run: 20, exploration: 0.1807404651835882, score: 14
# Scores: (min: 8, avg: 12.05, max: 23)
#
# Run: 21, exploration: 0.1710445669841008, score: 12
# Scores: (min: 8, avg: 12.047619047619047, max: 23)
#
# Run: 22, exploration: 0.16186880931761105, score: 12
# Scores: (min: 8, avg: 12.045454545454545, max: 23)
#
# Run: 23, exploration: 0.15241936258153677, score: 13
# Scores: (min: 8, avg: 12.08695652173913, max: 23)
#
# Run: 24, exploration: 0.14424276183128304, score: 12
# Scores: (min: 8, avg: 12.083333333333334, max: 23)
#
# Run: 25, exploration: 0.13788015278803506, score: 10
# Scores: (min: 8, avg: 12, max: 23)
#
# Run: 26, exploration: 0.13179820111243074, score: 10
# Scores: (min: 8, avg: 11.923076923076923, max: 23)
#
# Run: 27, exploration: 0.12598452688964626, score: 10
# Scores: (min: 8, avg: 11.851851851851851, max: 23)
#
# Run: 28, exploration: 0.1083950953617036, score: 31
# Scores: (min: 8, avg: 12.535714285714286, max: 31)
#
# Run: 29, exploration: 0.1, score: 18
# Scores: (min: 8, avg: 12.724137931034482, max: 31)
#
# Run: 30, exploration: 0.1, score: 25
# Scores: (min: 8, avg: 13.133333333333333, max: 31)
#
# Run: 31, exploration: 0.1, score: 37
# Scores: (min: 8, avg: 13.903225806451612, max: 37)
#
# Run: 32, exploration: 0.1, score: 30
# Scores: (min: 8, avg: 14.40625, max: 37)
#
# Run: 33, exploration: 0.1, score: 33
# Scores: (min: 8, avg: 14.969696969696969, max: 37)
#
# Run: 34, exploration: 0.1, score: 29
# Scores: (min: 8, avg: 15.382352941176471, max: 37)
#
# Run: 35, exploration: 0.1, score: 71
# Scores: (min: 8, avg: 16.97142857142857, max: 71)
#
# Run: 36, exploration: 0.1, score: 84
# Scores: (min: 8, avg: 18.833333333333332, max: 84)
#
# Run: 37, exploration: 0.1, score: 47
# Scores: (min: 8, avg: 19.594594594594593, max: 84)
#
# Run: 38, exploration: 0.1, score: 43
# Scores: (min: 8, avg: 20.210526315789473, max: 84)
#
# Run: 39, exploration: 0.1, score: 50
# Scores: (min: 8, avg: 20.974358974358974, max: 84)
#
# Run: 40, exploration: 0.1, score: 54
# Scores: (min: 8, avg: 21.8, max: 84)
#
# Run: 41, exploration: 0.1, score: 51
# Scores: (min: 8, avg: 22.51219512195122, max: 84)
#
# Run: 42, exploration: 0.1, score: 175
# Scores: (min: 8, avg: 26.142857142857142, max: 175)
#
# Run: 43, exploration: 0.1, score: 67
# Scores: (min: 8, avg: 27.093023255813954, max: 175)
#
# Run: 44, exploration: 0.1, score: 71
# Scores: (min: 8, avg: 28.09090909090909, max: 175)
#
# Run: 45, exploration: 0.1, score: 55
# Scores: (min: 8, avg: 28.68888888888889, max: 175)
#
# Run: 46, exploration: 0.1, score: 95
# Scores: (min: 8, avg: 30.130434782608695, max: 175)
#
# Run: 47, exploration: 0.1, score: 67
# Scores: (min: 8, avg: 30.914893617021278, max: 175)
#
# Run: 48, exploration: 0.1, score: 30
# Scores: (min: 8, avg: 30.895833333333332, max: 175)
#
# Run: 49, exploration: 0.1, score: 80
# Scores: (min: 8, avg: 31.897959183673468, max: 175)
#
# Run: 50, exploration: 0.1, score: 46
# Scores: (min: 8, avg: 32.18, max: 175)
#
# Run: 51, exploration: 0.1, score: 41
# Scores: (min: 8, avg: 32.35294117647059, max: 175)
#
# Run: 52, exploration: 0.1, score: 63
# Scores: (min: 8, avg: 32.94230769230769, max: 175)
#
# Run: 53, exploration: 0.1, score: 55
# Scores: (min: 8, avg: 33.35849056603774, max: 175)
#
# Run: 54, exploration: 0.1, score: 79
# Scores: (min: 8, avg: 34.2037037037037, max: 175)
#
# Run: 55, exploration: 0.1, score: 100
# Scores: (min: 8, avg: 35.4, max: 175)
#
# Run: 56, exploration: 0.1, score: 90
# Scores: (min: 8, avg: 36.375, max: 175)
#
# Run: 57, exploration: 0.1, score: 135
# Scores: (min: 8, avg: 38.10526315789474, max: 175)
#
# Run: 58, exploration: 0.1, score: 107
# Scores: (min: 8, avg: 39.293103448275865, max: 175)
#
# Run: 59, exploration: 0.1, score: 108
# Scores: (min: 8, avg: 40.45762711864407, max: 175)
#
# Run: 60, exploration: 0.1, score: 181
# Scores: (min: 8, avg: 42.8, max: 181)
#
# Run: 61, exploration: 0.1, score: 204
# Scores: (min: 8, avg: 45.442622950819676, max: 204)
#
# Run: 62, exploration: 0.1, score: 249
# Scores: (min: 8, avg: 48.725806451612904, max: 249)
#
# Run: 63, exploration: 0.1, score: 208
# Scores: (min: 8, avg: 51.25396825396825, max: 249)
#
# Run: 64, exploration: 0.1, score: 360
# Scores: (min: 8, avg: 56.078125, max: 360)
#
# Run: 65, exploration: 0.1, score: 225
# Scores: (min: 8, avg: 58.676923076923075, max: 360)
#
# Run: 66, exploration: 0.1, score: 246
# Scores: (min: 8, avg: 61.515151515151516, max: 360)
#
# Run: 67, exploration: 0.1, score: 172
# Scores: (min: 8, avg: 63.16417910447761, max: 360)
#
# Run: 68, exploration: 0.1, score: 280
# Scores: (min: 8, avg: 66.3529411764706, max: 360)
#
# Run: 69, exploration: 0.1, score: 297
# Scores: (min: 8, avg: 69.69565217391305, max: 360)
#
# Run: 70, exploration: 0.1, score: 271
# Scores: (min: 8, avg: 72.57142857142857, max: 360)
#
# Run: 71, exploration: 0.1, score: 271
# Scores: (min: 8, avg: 75.36619718309859, max: 360)
#
# Run: 72, exploration: 0.1, score: 235
# Scores: (min: 8, avg: 77.58333333333333, max: 360)
#
# Run: 73, exploration: 0.1, score: 251
# Scores: (min: 8, avg: 79.95890410958904, max: 360)
#
# Run: 74, exploration: 0.1, score: 167
# Scores: (min: 8, avg: 81.13513513513513, max: 360)
#
# Run: 75, exploration: 0.1, score: 200
# Scores: (min: 8, avg: 82.72, max: 360)
#
# Run: 76, exploration: 0.1, score: 187
# Scores: (min: 8, avg: 84.09210526315789, max: 360)
#
# Run: 77, exploration: 0.1, score: 322
# Scores: (min: 8, avg: 87.18181818181819, max: 360)
#
# Run: 78, exploration: 0.1, score: 238
# Scores: (min: 8, avg: 89.11538461538461, max: 360)
#
# Run: 79, exploration: 0.1, score: 235
# Scores: (min: 8, avg: 90.9620253164557, max: 360)
#
# Run: 80, exploration: 0.1, score: 256
# Scores: (min: 8, avg: 93.025, max: 360)
#
# Run: 81, exploration: 0.1, score: 241
# Scores: (min: 8, avg: 94.85185185185185, max: 360)
#
# Run: 82, exploration: 0.1, score: 232
# Scores: (min: 8, avg: 96.52439024390245, max: 360)
#
# Run: 83, exploration: 0.1, score: 347
# Scores: (min: 8, avg: 99.5421686746988, max: 360)
#
# Run: 84, exploration: 0.1, score: 266
# Scores: (min: 8, avg: 101.52380952380952, max: 360)
#
# Run: 85, exploration: 0.1, score: 190
# Scores: (min: 8, avg: 102.56470588235294, max: 360)
#
# Run: 86, exploration: 0.1, score: 246
# Scores: (min: 8, avg: 104.23255813953489, max: 360)
#
# Run: 87, exploration: 0.1, score: 432
# Scores: (min: 8, avg: 108, max: 432)
#
# Run: 88, exploration: 0.1, score: 225
# Scores: (min: 8, avg: 109.32954545454545, max: 432)
#
# Run: 89, exploration: 0.1, score: 279
# Scores: (min: 8, avg: 111.23595505617978, max: 432)
#
# Run: 90, exploration: 0.1, score: 221
# Scores: (min: 8, avg: 112.45555555555555, max: 432)
#
# Run: 91, exploration: 0.1, score: 231
# Scores: (min: 8, avg: 113.75824175824175, max: 432)
# Run: 92, exploration: 0.1, score: 255
# Scores: (min: 8, avg: 115.29347826086956, max: 432)
#
# Run: 93, exploration: 0.1, score: 191
# Scores: (min: 8, avg: 116.10752688172043, max: 432)
#
# Run: 94, exploration: 0.1, score: 200
# Scores: (min: 8, avg: 117, max: 432)
#
# Run: 95, exploration: 0.1, score: 225
# Scores: (min: 8, avg: 118.13684210526316, max: 432)
#
# Run: 96, exploration: 0.1, score: 210
# Scores: (min: 8, avg: 119.09375, max: 432)
#
# Run: 97, exploration: 0.1, score: 343
# Scores: (min: 8, avg: 121.4020618556701, max: 432)
#
# Run: 98, exploration: 0.1, score: 260
# Scores: (min: 8, avg: 122.81632653061224, max: 432)
#
# Run: 99, exploration: 0.1, score: 239
# Scores: (min: 8, avg: 123.98989898989899, max: 432)
#
# Run: 100, exploration: 0.1, score: 221
# Scores: (min: 8, avg: 124.96, max: 432)
#
# Run: 101, exploration: 0.1, score: 238
# Scores: (min: 8, avg: 127.24, max: 432)
#
# Run: 102, exploration: 0.1, score: 184
# Scores: (min: 8, avg: 128.92, max: 432)
#
# Run: 103, exploration: 0.1, score: 216
# Scores: (min: 8, avg: 130.85, max: 432)
#
# Run: 104, exploration: 0.1, score: 261
# Scores: (min: 8, avg: 133.37, max: 432)
#
# Run: 105, exploration: 0.1, score: 164
# Scores: (min: 8, avg: 134.92, max: 432)
#
# Run: 106, exploration: 0.1, score: 280
# Scores: (min: 8, avg: 137.59, max: 432)
#
# Run: 107, exploration: 0.1, score: 219
# Scores: (min: 9, avg: 139.7, max: 432)
#
# Run: 108, exploration: 0.1, score: 177
# Scores: (min: 9, avg: 141.37, max: 432)
#
# Run: 109, exploration: 0.1, score: 97
# Scores: (min: 9, avg: 142.24, max: 432)
#
# Run: 110, exploration: 0.1, score: 178
# Scores: (min: 9, avg: 143.93, max: 432)
#
# Run: 111, exploration: 0.1, score: 117
# Scores: (min: 9, avg: 144.97, max: 432)
#
# Run: 112, exploration: 0.1, score: 181
# Scores: (min: 9, avg: 146.68, max: 432)
#
# Run: 113, exploration: 0.1, score: 213
# Scores: (min: 9, avg: 148.71, max: 432)
#
# Run: 114, exploration: 0.1, score: 243
# Scores: (min: 9, avg: 151.02, max: 432)
#
# Run: 115, exploration: 0.1, score: 191
# Scores: (min: 10, avg: 152.84, max: 432)
#
# Run: 116, exploration: 0.1, score: 214
# Scores: (min: 10, avg: 154.8, max: 432)
#
# Run: 117, exploration: 0.1, score: 167
# Scores: (min: 10, avg: 156.33, max: 432)
#
# Run: 118, exploration: 0.1, score: 26
# Scores: (min: 10, avg: 156.48, max: 432)
#
# Run: 119, exploration: 0.1, score: 168
# Scores: (min: 10, avg: 158.03, max: 432)
#
# Run: 120, exploration: 0.1, score: 43
# Scores: (min: 10, avg: 158.32, max: 432)
#
# Run: 121, exploration: 0.1, score: 121
# Scores: (min: 10, avg: 159.41, max: 432)
#
# Run: 122, exploration: 0.1, score: 199
# Scores: (min: 10, avg: 161.28, max: 432)
#
# Run: 123, exploration: 0.1, score: 164
# Scores: (min: 10, avg: 162.79, max: 432)
#
# Run: 124, exploration: 0.1, score: 157
# Scores: (min: 10, avg: 164.24, max: 432)
#
# Run: 125, exploration: 0.1, score: 11
# Scores: (min: 10, avg: 164.25, max: 432)
#
# Run: 126, exploration: 0.1, score: 164
# Scores: (min: 10, avg: 165.79, max: 432)
#
# Run: 127, exploration: 0.1, score: 243
# Scores: (min: 11, avg: 168.12, max: 432)
#
# Run: 128, exploration: 0.1, score: 162
# Scores: (min: 11, avg: 169.43, max: 432)
#
# Run: 129, exploration: 0.1, score: 223
# Scores: (min: 11, avg: 171.48, max: 432)
#
# Run: 130, exploration: 0.1, score: 220
# Scores: (min: 11, avg: 173.43, max: 432)
#
# Run: 131, exploration: 0.1, score: 193
# Scores: (min: 11, avg: 174.99, max: 432)
#
# Run: 132, exploration: 0.1, score: 78
# Scores: (min: 11, avg: 175.47, max: 432)
#
# Run: 133, exploration: 0.1, score: 147
# Scores: (min: 11, avg: 176.61, max: 432)
#
# Run: 134, exploration: 0.1, score: 50
# Scores: (min: 11, avg: 176.82, max: 432)
#
# Run: 135, exploration: 0.1, score: 179
# Scores: (min: 11, avg: 177.9, max: 432)
#
# Run: 136, exploration: 0.1, score: 189
# Scores: (min: 11, avg: 178.95, max: 432)
#
# Run: 137, exploration: 0.1, score: 244
# Scores: (min: 11, avg: 180.92, max: 432)
#
# Run: 138, exploration: 0.1, score: 57
# Scores: (min: 11, avg: 181.06, max: 432)
#
# Run: 139, exploration: 0.1, score: 181
# Scores: (min: 11, avg: 182.37, max: 432)
#
# Run: 140, exploration: 0.1, score: 161
# Scores: (min: 11, avg: 183.44, max: 432)
#
# Run: 141, exploration: 0.1, score: 103
# Scores: (min: 11, avg: 183.96, max: 432)
#
# Run: 142, exploration: 0.1, score: 193
# Scores: (min: 11, avg: 184.14, max: 432)
#
# Run: 143, exploration: 0.1, score: 190
# Scores: (min: 11, avg: 185.37, max: 432)
#
# Run: 144, exploration: 0.1, score: 195
# Scores: (min: 11, avg: 186.61, max: 432)
#
# Run: 145, exploration: 0.1, score: 214
# Scores: (min: 11, avg: 188.2, max: 432)
#
# Run: 146, exploration: 0.1, score: 167
# Scores: (min: 11, avg: 188.92, max: 432)
#
# Run: 147, exploration: 0.1, score: 177
# Scores: (min: 11, avg: 190.02, max: 432)
#
# Run: 148, exploration: 0.1, score: 184
# Scores: (min: 11, avg: 191.56, max: 432)
#
# Run: 149, exploration: 0.1, score: 270
# Scores: (min: 11, avg: 193.46, max: 432)
#
# Run: 150, exploration: 0.1, score: 146
# Scores: (min: 11, avg: 194.46, max: 432)
#
# Run: 151, exploration: 0.1, score: 231
# Scores: (min: 11, avg: 196.36, max: 432)
#
# Solved in 51 runs, 151 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9888\682879775.py in <module>
# ----> 1 cartpole()
#
# ~\AppData\Local\Temp\ipykernel_9888\3596157709.py in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# ~\1CS-370\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.95  
LEARNING_RATE = 0.001  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.95  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()

# %%
cartpole()
# Out:
# Run: 1, exploration: 1.0, score: 11
# Scores: (min: 11, avg: 11, max: 11)
#
# Run: 2, exploration: 0.6634204312890623, score: 17
# Scores: (min: 11, avg: 14, max: 17)
#
# Run: 3, exploration: 0.37735360253530714, score: 12
# Scores: (min: 11, avg: 13.333333333333334, max: 17)
#
# Run: 4, exploration: 0.18402591023557577, score: 15
# Scores: (min: 11, avg: 13.75, max: 17)
#
# Run: 5, exploration: 0.11018311023500525, score: 11
# Scores: (min: 11, avg: 13.2, max: 17)
#
# Run: 6, exploration: 0.07309772651287748, score: 9
# Scores: (min: 9, avg: 12.5, max: 17)
#
# Run: 7, exploration: 0.05104686868360325, score: 8
# Scores: (min: 8, avg: 11.857142857142858, max: 17)
#
# Run: 8, exploration: 0.02620450591493621, score: 14
# Scores: (min: 8, avg: 12.125, max: 17)
#
# Run: 9, exploration: 0.017384604615803764, score: 9
# Scores: (min: 8, avg: 11.777777777777779, max: 17)
#
# Run: 10, exploration: 0.010408804957535735, score: 11
# Scores: (min: 8, avg: 11.7, max: 17)
#
# Run: 11, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.454545454545455, max: 17)
#
# Run: 12, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.25, max: 17)
#
# Run: 13, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 11, max: 17)
#
# Run: 14, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 11.5, max: 18)
#
# Run: 15, exploration: 0.01, score: 40
# Scores: (min: 8, avg: 13.4, max: 40)
#
# Run: 16, exploration: 0.01, score: 66
# Scores: (min: 8, avg: 16.6875, max: 66)
#
# Run: 17, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 17, max: 66)
#
# Run: 18, exploration: 0.01, score: 43
# Scores: (min: 8, avg: 18.444444444444443, max: 66)
#
# Run: 19, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 19.36842105263158, max: 66)
#
# Run: 20, exploration: 0.01, score: 132
# Scores: (min: 8, avg: 25, max: 132)
#
# Run: 21, exploration: 0.01, score: 77
# Scores: (min: 8, avg: 27.476190476190474, max: 132)
#
# Run: 22, exploration: 0.01, score: 106
# Scores: (min: 8, avg: 31.045454545454547, max: 132)
#
# Run: 23, exploration: 0.01, score: 62
# Scores: (min: 8, avg: 32.391304347826086, max: 132)
#
# Run: 24, exploration: 0.01, score: 118
# Scores: (min: 8, avg: 35.958333333333336, max: 132)
#
# Run: 25, exploration: 0.01, score: 42
# Scores: (min: 8, avg: 36.2, max: 132)
#
# Run: 26, exploration: 0.01, score: 77
# Scores: (min: 8, avg: 37.76923076923077, max: 132)
#
# Run: 27, exploration: 0.01, score: 92
# Scores: (min: 8, avg: 39.77777777777778, max: 132)
#
# Run: 28, exploration: 0.01, score: 83
# Scores: (min: 8, avg: 41.32142857142857, max: 132)
#
# Run: 29, exploration: 0.01, score: 57
# Scores: (min: 8, avg: 41.86206896551724, max: 132)
#
# Run: 30, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 41.36666666666667, max: 132)
#
# Run: 31, exploration: 0.01, score: 38
# Scores: (min: 8, avg: 41.25806451612903, max: 132)
#
# Run: 32, exploration: 0.01, score: 64
# Scores: (min: 8, avg: 41.96875, max: 132)
#
# Run: 33, exploration: 0.01, score: 135
# Scores: (min: 8, avg: 44.78787878787879, max: 135)
#
# Run: 34, exploration: 0.01, score: 85
# Scores: (min: 8, avg: 45.970588235294116, max: 135)
#
# Run: 35, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 45.457142857142856, max: 135)
#
# Run: 36, exploration: 0.01, score: 63
# Scores: (min: 8, avg: 45.94444444444444, max: 135)
#
# Run: 37, exploration: 0.01, score: 96
# Scores: (min: 8, avg: 47.2972972972973, max: 135)
#
# Run: 38, exploration: 0.01, score: 89
# Scores: (min: 8, avg: 48.39473684210526, max: 135)
#
# Run: 39, exploration: 0.01, score: 117
# Scores: (min: 8, avg: 50.15384615384615, max: 135)
#
# Run: 40, exploration: 0.01, score: 109
# Scores: (min: 8, avg: 51.625, max: 135)
#
# Run: 41, exploration: 0.01, score: 123
# Scores: (min: 8, avg: 53.36585365853659, max: 135)
#
# Run: 42, exploration: 0.01, score: 73
# Scores: (min: 8, avg: 53.833333333333336, max: 135)
#
# Run: 43, exploration: 0.01, score: 95
# Scores: (min: 8, avg: 54.7906976744186, max: 135)
#
# Run: 44, exploration: 0.01, score: 137
# Scores: (min: 8, avg: 56.65909090909091, max: 137)
#
# Run: 45, exploration: 0.01, score: 92
# Scores: (min: 8, avg: 57.44444444444444, max: 137)
#
# Run: 46, exploration: 0.01, score: 186
# Scores: (min: 8, avg: 60.23913043478261, max: 186)
#
# Run: 47, exploration: 0.01, score: 123
# Scores: (min: 8, avg: 61.57446808510638, max: 186)
#
# Run: 48, exploration: 0.01, score: 188
# Scores: (min: 8, avg: 64.20833333333333, max: 188)
#
# Run: 49, exploration: 0.01, score: 142
# Scores: (min: 8, avg: 65.79591836734694, max: 188)
#
# Run: 50, exploration: 0.01, score: 176
# Scores: (min: 8, avg: 68, max: 188)
#
# Run: 51, exploration: 0.01, score: 144
# Scores: (min: 8, avg: 69.49019607843137, max: 188)
#
# Run: 52, exploration: 0.01, score: 248
# Scores: (min: 8, avg: 72.92307692307692, max: 248)
#
# Run: 53, exploration: 0.01, score: 305
# Scores: (min: 8, avg: 77.30188679245283, max: 305)
#
# Run: 54, exploration: 0.01, score: 254
# Scores: (min: 8, avg: 80.57407407407408, max: 305)
#
# Run: 55, exploration: 0.01, score: 257
# Scores: (min: 8, avg: 83.78181818181818, max: 305)
#
# Run: 56, exploration: 0.01, score: 310
# Scores: (min: 8, avg: 87.82142857142857, max: 310)
#
# Run: 57, exploration: 0.01, score: 146
# Scores: (min: 8, avg: 88.84210526315789, max: 310)
#
# Run: 58, exploration: 0.01, score: 324
# Scores: (min: 8, avg: 92.89655172413794, max: 324)
#
# Run: 59, exploration: 0.01, score: 146
# Scores: (min: 8, avg: 93.79661016949153, max: 324)
#
# Run: 60, exploration: 0.01, score: 139
# Scores: (min: 8, avg: 94.55, max: 324)
#
# Run: 61, exploration: 0.01, score: 188
# Scores: (min: 8, avg: 96.08196721311475, max: 324)
#
# Run: 62, exploration: 0.01, score: 279
# Scores: (min: 8, avg: 99.03225806451613, max: 324)
#
# Run: 63, exploration: 0.01, score: 204
# Scores: (min: 8, avg: 100.6984126984127, max: 324)
#
# Run: 64, exploration: 0.01, score: 249
# Scores: (min: 8, avg: 103.015625, max: 324)
#
# Run: 65, exploration: 0.01, score: 198
# Scores: (min: 8, avg: 104.47692307692307, max: 324)
#
# Run: 66, exploration: 0.01, score: 232
# Scores: (min: 8, avg: 106.4090909090909, max: 324)
#
# Run: 67, exploration: 0.01, score: 194
# Scores: (min: 8, avg: 107.71641791044776, max: 324)
#
# Run: 68, exploration: 0.01, score: 197
# Scores: (min: 8, avg: 109.02941176470588, max: 324)
#
# Run: 69, exploration: 0.01, score: 189
# Scores: (min: 8, avg: 110.18840579710145, max: 324)
#
# Run: 70, exploration: 0.01, score: 170
# Scores: (min: 8, avg: 111.04285714285714, max: 324)
#
# Run: 71, exploration: 0.01, score: 199
# Scores: (min: 8, avg: 112.28169014084507, max: 324)
#
# Run: 72, exploration: 0.01, score: 143
# Scores: (min: 8, avg: 112.70833333333333, max: 324)
#
# Run: 73, exploration: 0.01, score: 225
# Scores: (min: 8, avg: 114.24657534246575, max: 324)
#
# Run: 74, exploration: 0.01, score: 225
# Scores: (min: 8, avg: 115.74324324324324, max: 324)
#
# Run: 75, exploration: 0.01, score: 231
# Scores: (min: 8, avg: 117.28, max: 324)
#
# Run: 76, exploration: 0.01, score: 237
# Scores: (min: 8, avg: 118.85526315789474, max: 324)
#
# Run: 77, exploration: 0.01, score: 183
# Scores: (min: 8, avg: 119.68831168831169, max: 324)
#
# Run: 78, exploration: 0.01, score: 146
# Scores: (min: 8, avg: 120.02564102564102, max: 324)
#
# Run: 79, exploration: 0.01, score: 165
# Scores: (min: 8, avg: 120.59493670886076, max: 324)
#
# Run: 80, exploration: 0.01, score: 113
# Scores: (min: 8, avg: 120.5, max: 324)
#
# Run: 81, exploration: 0.01, score: 174
# Scores: (min: 8, avg: 121.1604938271605, max: 324)
#
# Run: 82, exploration: 0.01, score: 173
# Scores: (min: 8, avg: 121.79268292682927, max: 324)
#
# Run: 83, exploration: 0.01, score: 310
# Scores: (min: 8, avg: 124.06024096385542, max: 324)
#
# Run: 84, exploration: 0.01, score: 167
# Scores: (min: 8, avg: 124.57142857142857, max: 324)
#
# Run: 85, exploration: 0.01, score: 168
# Scores: (min: 8, avg: 125.08235294117647, max: 324)
#
# Run: 86, exploration: 0.01, score: 197
# Scores: (min: 8, avg: 125.9186046511628, max: 324)
#
# Run: 87, exploration: 0.01, score: 145
# Scores: (min: 8, avg: 126.13793103448276, max: 324)
#
# Run: 88, exploration: 0.01, score: 211
# Scores: (min: 8, avg: 127.10227272727273, max: 324)
#
# Run: 89, exploration: 0.01, score: 190
# Scores: (min: 8, avg: 127.80898876404494, max: 324)
#
# Run: 90, exploration: 0.01, score: 189
# Scores: (min: 8, avg: 128.48888888888888, max: 324)
#
# Run: 91, exploration: 0.01, score: 329
# Scores: (min: 8, avg: 130.69230769230768, max: 329)
#
# Run: 92, exploration: 0.01, score: 117
# Scores: (min: 8, avg: 130.54347826086956, max: 329)
# Run: 93, exploration: 0.01, score: 162
# Scores: (min: 8, avg: 130.88172043010752, max: 329)
#
# Run: 94, exploration: 0.01, score: 92
# Scores: (min: 8, avg: 130.46808510638297, max: 329)
#
# Run: 95, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 129.45263157894738, max: 329)
#
# Run: 96, exploration: 0.01, score: 47
# Scores: (min: 8, avg: 128.59375, max: 329)
#
# Run: 97, exploration: 0.01, score: 128
# Scores: (min: 8, avg: 128.58762886597938, max: 329)
#
# Run: 98, exploration: 0.01, score: 283
# Scores: (min: 8, avg: 130.16326530612244, max: 329)
#
# Run: 99, exploration: 0.01, score: 155
# Scores: (min: 8, avg: 130.41414141414143, max: 329)
#
# Run: 100, exploration: 0.01, score: 100
# Scores: (min: 8, avg: 130.11, max: 329)
#
# Run: 101, exploration: 0.01, score: 490
# Scores: (min: 8, avg: 134.9, max: 490)
#
# Run: 102, exploration: 0.01, score: 64
# Scores: (min: 8, avg: 135.37, max: 490)
#
# Run: 103, exploration: 0.01, score: 175
# Scores: (min: 8, avg: 137, max: 490)
#
# Run: 104, exploration: 0.01, score: 147
# Scores: (min: 8, avg: 138.32, max: 490)
#
# Run: 105, exploration: 0.01, score: 176
# Scores: (min: 8, avg: 139.97, max: 490)
#
# Run: 106, exploration: 0.01, score: 132
# Scores: (min: 8, avg: 141.2, max: 490)
#
# Run: 107, exploration: 0.01, score: 154
# Scores: (min: 8, avg: 142.66, max: 490)
#
# Run: 108, exploration: 0.01, score: 151
# Scores: (min: 8, avg: 144.03, max: 490)
#
# Run: 109, exploration: 0.01, score: 140
# Scores: (min: 8, avg: 145.34, max: 490)
#
# Run: 110, exploration: 0.01, score: 253
# Scores: (min: 8, avg: 147.76, max: 490)
#
# Run: 111, exploration: 0.01, score: 218
# Scores: (min: 8, avg: 149.85, max: 490)
#
# Run: 112, exploration: 0.01, score: 98
# Scores: (min: 8, avg: 150.74, max: 490)
#
# Run: 113, exploration: 0.01, score: 127
# Scores: (min: 18, avg: 151.93, max: 490)
#
# Run: 114, exploration: 0.01, score: 195
# Scores: (min: 22, avg: 153.7, max: 490)
#
# Run: 115, exploration: 0.01, score: 49
# Scores: (min: 22, avg: 153.79, max: 490)
#
# Run: 116, exploration: 0.01, score: 247
# Scores: (min: 22, avg: 155.6, max: 490)
#
# Run: 117, exploration: 0.01, score: 122
# Scores: (min: 27, avg: 156.6, max: 490)
#
# Run: 118, exploration: 0.01, score: 47
# Scores: (min: 27, avg: 156.64, max: 490)
#
# Run: 119, exploration: 0.01, score: 209
# Scores: (min: 27, avg: 158.37, max: 490)
#
# Run: 120, exploration: 0.01, score: 43
# Scores: (min: 27, avg: 157.48, max: 490)
#
# Run: 121, exploration: 0.01, score: 105
# Scores: (min: 27, avg: 157.76, max: 490)
#
# Run: 122, exploration: 0.01, score: 129
# Scores: (min: 27, avg: 157.99, max: 490)
#
# Run: 123, exploration: 0.01, score: 121
# Scores: (min: 27, avg: 158.58, max: 490)
#
# Run: 124, exploration: 0.01, score: 194
# Scores: (min: 27, avg: 159.34, max: 490)
#
# Run: 125, exploration: 0.01, score: 116
# Scores: (min: 27, avg: 160.08, max: 490)
#
# Run: 126, exploration: 0.01, score: 172
# Scores: (min: 27, avg: 161.03, max: 490)
#
# Run: 127, exploration: 0.01, score: 296
# Scores: (min: 27, avg: 163.07, max: 490)
#
# Run: 128, exploration: 0.01, score: 193
# Scores: (min: 27, avg: 164.17, max: 490)
#
# Run: 129, exploration: 0.01, score: 381
# Scores: (min: 27, avg: 167.41, max: 490)
#
# Run: 130, exploration: 0.01, score: 207
# Scores: (min: 28, avg: 169.21, max: 490)
#
# Run: 131, exploration: 0.01, score: 225
# Scores: (min: 28, avg: 171.08, max: 490)
#
# Run: 132, exploration: 0.01, score: 102
# Scores: (min: 28, avg: 171.46, max: 490)
#
# Run: 133, exploration: 0.01, score: 237
# Scores: (min: 28, avg: 172.48, max: 490)
#
# Run: 134, exploration: 0.01, score: 500
# Scores: (min: 28, avg: 176.63, max: 500)
#
# Run: 135, exploration: 0.01, score: 133
# Scores: (min: 34, avg: 177.68, max: 500)
#
# Run: 136, exploration: 0.01, score: 500
# Scores: (min: 34, avg: 182.05, max: 500)
#
# Run: 137, exploration: 0.01, score: 295
# Scores: (min: 34, avg: 184.04, max: 500)
#
# Run: 138, exploration: 0.01, score: 500
# Scores: (min: 34, avg: 188.15, max: 500)
#
# Run: 139, exploration: 0.01, score: 264
# Scores: (min: 34, avg: 189.62, max: 500)
#
# Run: 140, exploration: 0.01, score: 358
# Scores: (min: 34, avg: 192.11, max: 500)
#
# Run: 141, exploration: 0.01, score: 343
# Scores: (min: 34, avg: 194.31, max: 500)
#
# Run: 142, exploration: 0.01, score: 12
# Scores: (min: 12, avg: 193.7, max: 500)
#
# Run: 143, exploration: 0.01, score: 307
# Scores: (min: 12, avg: 195.82, max: 500)
#
# Solved in 43 runs, 143 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9888\682879775.py in <module>
# ----> 1 cartpole()
#
# ~\AppData\Local\Temp\ipykernel_9888\2282118865.py in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# ~\1CS-370\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %%
Explain how reinforcement learning concepts apply to the cartpole problem.
What is the goal of the agent in this case?
The goal of the agent is to balance a pole vertically on a rotating pivot point by moving the pole base horizontally.
The agent must determine what the appropriate movements are for the cart (the base), while not exceeding a prespecified distance
from the initial position.

What are the various state values?
The various state value used are really a result of how the cartpole problem is represented. For example,
problem could be represented digitally, or as a physical model. In "Reinforcement Learning Concept on Cart-Pole with DQN",
Phy expounds on this idea, noting that "A state can be the current frame (in pixels) or it can be some 
other information that can represent the cart-pole, for instance, the velocity and position of the cart, 
the angle of the pole and pole velocity at the tip" (Phy, 2019).

What are the possible actions that can be performed?
The possible actions that can occur are for the cart to move left or right, and these actions can occur in 
rapid succession seperated by a small time inteval.

What reinforcement algorithm is used for this problem?
Deep Q-Learning is used for this problem, allowing a rapid estimation of Q-Learning with low cmputational 
overhead. According to Balawejder, "experience replay that randomizes over the data, thereby removing 
correlations in the observation sequence and smoothing over changes in the data distribution. To perform 
experience replay we store the agent’s experiences et=(st,at,rt,st+1)" (Balawejder, 2022). In the equation for experience,
the terms refer to four contributing factors to experience at time "t" (these being state, action, reward, 
and future states)

Analyze how experience replay is applied to the cartpole problem.
Experience replay "looks back" on past attempts to determine what the best attempts have looked like prior to the current attempt.
The model incorporates its best guess about future states into the determination of the next action in an
attempt to maximize total reward. This information is used to increase the likelihood of successful action-state pairings.

How does experience replay work in this algorithm?
Random actions are executed in an emulator and reward values are associated with the transitions from 
one state to another. Total reward for the transitions is optimized, with gradient descent, by updating 
the weights in the neural net model.

What is the effect of introducing a discount factor for calculating the future rewards? The discount factor
determines how much value is placed on the results of future actions. A factor of zero results in a greedy 
algorithm, while a factor of one will cause the model to evaluate each of its actions based on the sum 
total of all of its future rewards. Intermediary values discount actions that occur further in the future, 
allowing actions closer to the present to weigh more heavily in the selection of action.

Analyze how neural networks are used in deep Q-learning.
Q-learning creates a table of actions and states and updates the table to represent approaches that are more successful. For 
complicated tasks with a large number of table entries, the amount of time required for operating such a frameworks can become
computationally expensive. In deep Q-learning, Machine learning can be used to approximate the Q-learning model, with the trained
obtaining high performance with a low amount of run-time computation.

Explain the neural network architecture that is used in the cartpole problem.
The deep Q-Learning model should use at least one hidden layer; different numbers of hidden layers can be used for different instances.
The input layer is made up of all of the possible states, while the output layer is comprised of all possible actions. Each output 
neuron predicts the Q-value for that action at each step. The output with the maximum Q-value is the decided action for the current 
step.

How does the neural network make the Q-learning algorithm more efficient?
In normal Q-learning, a table is maintained with all possible states paired with actions that have performed well as responses to
each state. Each time the table needs to be updated, written to, or queried the computer system that the model runs on uses up 
computer cycles. For complex activities. this table can grow to a size that grows the time-complexity of the Q-learning model to 
a high level. Deep Q-learning reduces the run-time complexity of the model significantly by storing the table architecture in the
complexity of the neural network weights (representing a large amount of pre-computation). The model is trained to approximate the
solutions represented in the unteneble Q-learning table; once trained the deep learning version maps the correct action to the 
current state with very little further computation. 

What difference do you see in the algorithm performance when you increase or decrease the learning rate?
The initial learning rate of 0.001 resulted in a model solution in 72 runs (172 total runs). When the learning rate was doubled to
0.002, the solution was found in 565 runs (665 total runs). Order of magnitude deviations from the initial learning rate of 0.001,
in either direction, resulted in performance loss. Thus, while just a small increase in learning rate resulted in a large degredation
in performance, performance degradation is also an issue for very small learning rate values. 


References

Balawejder, M. (2022, February 20). Solving open ai's cartpole using reinforcement learning part-2. Medium. Retrieved June 4, 2022, 
    from https://medium.com/analytics-vidhya/solving-open-ais-cartpole-using-reinforcement-learning-part-2-73848cbda4f1 
    
Phy, V. (2019, November 4). Reinforcement learning concept on CART-pole with DQN. Medium. Retrieved June 4, 2022, 
    from https://towardsdatascience.com/reinforcement-learning-concept-on-cart-pole-with-dqn-799105ca670

# %% [markdown]
# Note: If the code is running properly, you should begin to see output appearing above this code block. It will take several minutes, so it is recommended that you let this code run in the background while completing other work. When the code has finished, it will print output saying, "Solved in _ runs, _ total runs."
#
# You may see an error about not having an exit command. This error does not affect the program's functionality and results from the steps taken to convert the code from Python 2.x to Python 3. Please disregard this error.
